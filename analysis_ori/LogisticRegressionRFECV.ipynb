# %%
# !pip install pymysql
# !sudo apt-get install -y fonts-nanum # 나눔 폰트 설치 (설치 후 런타임 재시작하고 코드 실행)
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pymysql in /usr/local/lib/python3.7/dist-packages (1.0.2)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import itertools
import pandas as pd
from sqlalchemy import create_engine
import pymysql
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import matplotlib.font_manager as fm
from matplotlib import rc
import warnings
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.feature_selection import RFECV
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
import time
import statsmodels.api as sm
from glob import glob

warnings.filterwarnings(action='ignore')
mpl.rcParams['axes.unicode_minus'] = False
rc('font', family='NanumBarunGothic')

endpoint = 'dao.c51deksujiip.ap-northeast-2.rds.amazonaws.com'
schema = 'dao'
db_connection_str = 'mysql+pymysql://admin:ekfkawnl@{}/{}'.format(endpoint, schema)
try :
    db_connection = create_engine(db_connection_str)
    conn = db_connection.connect()
except :
    print('fail to connect db')

def load_data_from_rds(tabel_name):
  sql = "SELECT * FROM {}".format(tabel_name)
  df = pd.read_sql(sql, db_connection)
  return df

# %%
def preprocess_df(df, onehot_col=None, scaling_col=None, drop_col = None, labeling_col = None, scaling_func=MinMaxScaler) :
    """
    :param df: 사용할 데이터프레임
    :param onehot_col: default = None, 원핫인코딩할 컬럼 리스트
    :param scaling_col: default = None, 스케일링할 컬럼 리스트
    :param drop_col: default = None, 사용하지 않을 컬럼 리스트
    :param labeling_col: default = None, 라벨링이 필요한 컬럼 리스트
    :param scaling_func: 스케일링시 사용할 컬럼, MinMaxScaler or StandardScaler
    :return: 전처리 된 데이터 프레임
    """
    if drop_col is not None :
        df = df.drop(drop_col, axis=1)
    if onehot_col is not None:
        df = pd.get_dummies(df, colums=onehot_col)
    if scaling_col is not None :
        for c in scaling_col :
            scaler = scaling_func()
            scaler.fit(df[[c]])
            df[c] = scaler.transform(df[[c]])
    if labeling_col is not None :
        for c in labeling_col :
            encoder = LabelEncoder()
            encoder.fit(df[c])
            df[c] = encoder.transform(df[c])
    return df

# %%
# GridSearchCV의 최적 하이퍼파라미터로 학습된 Estimator 반환하는 함수
def optimizing_lr(clf, train_x, train_y):
  parameters = {'penalty': ['l1','l2','elasticnet','none'],
                'C': np.arange(0,1,0.1),
                'random_state': range(3,7,2)}
  start = time.time()
  grid_cv = GridSearchCV(clf, param_grid=parameters, n_jobs=-1, scoring='accuracy', cv=5)
  grid_cv.fit(train_x, train_y)

  #최적의 하이퍼 파라미터 출력
  print('GridSearch 수행시간 : ', time.time()-start)
  print('최적 하이퍼 파라미터 :',grid_cv.best_params_)

  return grid_cv.best_estimator_

# %%
def logistic_regression(train_x, train_y, feature_importance = False, optimizing = False):

  # logistic regression
  lr_clf = LogisticRegression()

  # optimizing parameters
  if optimizing :
    lr_clf = optimizing_lr(lr_clf, train_x, train_y)
  else:
    lr_clf.fit(train_x, train_y)

  return lr_clf

# %%
# RFECV로 선택된 변수를 반환하는 함수
def rfecv_lr(clf, train_x, train_y):
  min_features_to_select=1
  rfe_cv = RFECV(clf, step=1, cv=5, min_features_to_select=min_features_to_select)
  rfe_cv.fit(train_x, train_y)

  # 최적의 변수 개수 출력
  print("Optimal number of features : %d" % rfe_cv.n_features_)

  # plt.figure()
  # plt.xlabel("Number of features selected")
  # plt.ylabel("Cross validation score (accuracy)")
  # plt.plot(
  #   range(min_features_to_select, len(rfe_cv.grid_scores_) + min_features_to_select),
  #   rfe_cv.grid_scores_,)
  # plt.show()

  return train_x.columns[rfe_cv.support_]

# %%
def evalutation_lf(test_y, pred_y):
  # 평가
  acc = accuracy_score(test_y, pred_y)
  f1 = f1_score(test_y, pred_y, average='macro')

  result = pd.DataFrame([['Logistic Regression RFECV', acc, f1]],
                         columns = ['Model', 'Accuracy', 'F1Score'])
  display(result)

# %%
def summary_lr(x, y):
  con_x = sm.add_constant(x)
  model = sm.OLS(y, con_x)
  result = model.fit()
  print(result.summary())

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
overpass_list = glob('/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/*overpass*.csv')
overpass_list = [p.replace('\\', '/') for p in overpass_list]
print(overpass_list)
tunnel_list = glob('/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/*tunnel*.csv')
tunnel_list = [p.replace('\\', '/') for p in tunnel_list]
print(tunnel_list)
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/overpass_knn2_median.csv', '/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/overpass_knn5_drop.csv', '/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/overpass_knn3_median.csv', '/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/overpass_knn5_median.csv', '/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/overpass_mean_drop.csv', '/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/overpass_mean_median.csv', '/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/overpass_knn2_drop.csv', '/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/overpass_knn1_drop.csv', '/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/overpass_knn3_drop.csv', '/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/overpass_knn4_median.csv', '/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/overpass_knn4_drop.csv', '/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/overpass_knn1_median.csv']
# ['/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/tunnel_mean_drop.csv', '/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/tunnel_knn3_median.csv', '/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/tunnel_knn2_median.csv', '/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/tunnel_knn1_median.csv', '/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/tunnel_knn5_drop.csv', '/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/tunnel_knn4_median.csv', '/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/tunnel_knn5_median.csv', '/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/tunnel_knn2_drop.csv', '/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/tunnel_mean_median.csv', '/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/tunnel_knn1_drop.csv', '/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/tunnel_knn3_drop.csv', '/content/drive/MyDrive/Colab Notebooks/데청캠_2팀/MainData/prepro/tunnel_knn4_drop.csv']

# %%
onehot_col = ['지형기호(2.3km)', '최우점식물군락']
scaling_col = ['폭(m)', '연장(m)', '주변 로드킬 빈도', '산책로까지의 최단 거리(km)', '농가까지의 거리(km)', '도로 최고제한속도(km/h)',
               '하천거리(km)', '주변 동물종 개수', '등산로까지 최단거리(km)', '유도울타리_연장_m', '유도울타리_높이_m', '교통량', '건물까지거리(km)']
drop_col = ['번호', '위도', '경도', '생태통로_유형', '이용확인종_수', '유도울타리_위도_2.3km', '유도울타리_경도_2.3km', '식물군락명']
scaling_col_tunnel = scaling_col + ['높이(m)', '개방도']

# %% [markdown]
# # 육교형

# %%
for case in overpass_list :
  df = pd.read_csv(case, encoding='cp949')
  name = case.split('/')[-1].split('.')[0]
  df = preprocess_df(df, drop_col=drop_col, labeling_col=onehot_col, scaling_col=scaling_col, scaling_func=StandardScaler)
 
  # x, y
  x=df.drop('생태통로_효율성', axis=1)
  y=df['생태통로_효율성']

  # train & test set
  train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.2, stratify=df['생태통로_효율성'])

  # logistic regression
  lr_clf =logistic_regression(train_x, train_y, optimizing=True)
  pred_y = lr_clf.predict(test_x)

  # evaluation
  evalutation_lf(test_y, pred_y)

  # summary
  summary_lr(train_x, train_y)

  # rfecv
  selected_x = rfecv_lr(lr_clf, train_x, train_y)

  # RFECV로 선택된 변수로 logistic regression
  lr_clf = logistic_regression(train_x[selected_x], train_y, optimizing=True)
  pred_y = lr_clf.predict(test_x[selected_x])

  # evaluation
  evalutation_lf(test_y, pred_y)

  # summary
  summary_lr(train_x[selected_x], train_y)
# Out:
# GridSearch 수행시간 :  13.121912240982056
# 최적 하이퍼 파라미터 : {'C': 0.5, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV  0.533333  0.414656
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.162
# Model:                            OLS   Adj. R-squared:                  0.086
# Method:                 Least Squares   F-statistic:                     2.119
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):            0.00457
# Time:                        09:04:54   Log-Likelihood:                -220.32
# No. Observations:                 240   AIC:                             482.6
# Df Residuals:                     219   BIC:                             555.7
# Df Model:                          20
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.0622      0.252      4.217      0.000       0.566       1.559
# 차선_수                -0.0375      0.120     -0.312      0.755      -0.274       0.199
# 등산객_이용빈도            -0.1452      0.061     -2.396      0.017      -0.265      -0.026
# 폭(m)                 0.1053      0.063      1.667      0.097      -0.019       0.230
# 연장(m)               -0.0292      0.085     -0.345      0.731      -0.196       0.138
# 경사도                  0.0469      0.049      0.966      0.335      -0.049       0.143
# 주변 로드킬 빈도           -0.9669      0.440     -2.198      0.029      -1.834      -0.100
# 산책로까지의 최단 거리(km)    -0.1531      0.079     -1.934      0.054      -0.309       0.003
# 농가까지의 거리(km)         0.4872      0.331      1.473      0.142      -0.165       1.139
# 도로 최고제한속도(km/h)      0.0173      0.213      0.081      0.936      -0.402       0.437
# 주변 동물종 개수           -0.0717      0.099     -0.725      0.469      -0.267       0.123
# 주변동물 출현빈도            0.0086      0.028      0.309      0.757      -0.046       0.064
# 지형기호(2.3km)          0.0168      0.019      0.870      0.386      -0.021       0.055
# 하천거리(km)            -0.0080      0.056     -0.142      0.887      -0.119       0.103
# 등산로까지 최단거리(km)      -0.0357      0.049     -0.725      0.469      -0.133       0.061
# 유도울타리_연장_m          -0.1886      0.116     -1.627      0.105      -0.417       0.040
# 유도울타리_높이_m           0.1707      0.119      1.440      0.151      -0.063       0.404
# 교통량                  0.1701      0.076      2.248      0.026       0.021       0.319
# 환경영향평가점수             0.0270      0.040      0.668      0.505      -0.053       0.107
# 건물까지거리(km)           0.4118      0.183      2.253      0.025       0.052       0.772
# 최우점식물군락             -0.0404      0.017     -2.339      0.020      -0.074      -0.006
# ==============================================================================
# Omnibus:                        1.365   Durbin-Watson:                   1.959
# Prob(Omnibus):                  0.505   Jarque-Bera (JB):                1.288
# Skew:                           0.179   Prob(JB):                        0.525
# Kurtosis:                       2.980   Cond. No.                         115.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Optimal number of features : 1
# GridSearch 수행시간 :  4.762351751327515
# 최적 하이퍼 파라미터 : {'C': 0.0, 'penalty': 'none', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV  0.666667  0.487356
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.154
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):              0.284
# Time:                        09:05:04   Log-Likelihood:                -240.97
# No. Observations:                 240   AIC:                             485.9
# Df Residuals:                     238   BIC:                             492.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9423      0.043     22.010      0.000       0.858       1.027
# 주변 로드킬 빈도      0.0461      0.043      1.074      0.284      -0.038       0.131
# ==============================================================================
# Omnibus:                       11.446   Durbin-Watson:                   1.906
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):                6.591
# Skew:                           0.229   Prob(JB):                       0.0370
# Kurtosis:                       2.330   Cond. No.                         1.01
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GridSearch 수행시간 :  12.958294153213501
# 최적 하이퍼 파라미터 : {'C': 0.0, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV  0.405405  0.192308
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.155
# Model:                            OLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     1.214
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):              0.257
# Time:                        09:05:17   Log-Likelihood:                -170.59
# No. Observations:                 146   AIC:                             381.2
# Df Residuals:                     126   BIC:                             440.9
# Df Model:                          19
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.6209      0.402      4.033      0.000       0.825       2.416
# 차선_수                -0.1733      0.151     -1.150      0.252      -0.472       0.125
# 등산객_이용빈도            -0.0946      0.082     -1.148      0.253      -0.258       0.069
# 폭(m)                 0.0608      0.087      0.697      0.487      -0.112       0.234
# 연장(m)               -0.0529      0.089     -0.598      0.551      -0.228       0.122
# 경사도                 -0.0220      0.059     -0.371      0.711      -0.139       0.095
# 주변 로드킬 빈도        -4.169e-16   1.48e-16     -2.826      0.005   -7.09e-16   -1.25e-16
# 산책로까지의 최단 거리(km)    -0.0734      0.089     -0.822      0.413      -0.250       0.103
# 농가까지의 거리(km)         0.0501      0.083      0.607      0.545      -0.113       0.213
# 도로 최고제한속도(km/h)      0.1890      0.108      1.755      0.082      -0.024       0.402
# 주변 동물종 개수            0.0978      0.183      0.534      0.595      -0.265       0.461
# 주변동물 출현빈도           -0.0531      0.044     -1.213      0.227      -0.140       0.034
# 지형기호(2.3km)         -0.0189      0.025     -0.754      0.452      -0.068       0.031
# 하천거리(km)             0.0499      0.077      0.645      0.520      -0.103       0.203
# 등산로까지 최단거리(km)       0.0006      0.080      0.008      0.994      -0.157       0.159
# 유도울타리_연장_m          -0.0844      0.159     -0.529      0.597      -0.400       0.231
# 유도울타리_높이_m           0.0336      0.160      0.210      0.834      -0.283       0.350
# 교통량                  0.1946      0.112      1.745      0.083      -0.026       0.415
# 환경영향평가점수             0.0280      0.052      0.541      0.589      -0.074       0.131
# 건물까지거리(km)           0.2637      0.082      3.229      0.002       0.102       0.425
# 최우점식물군락             -0.0335      0.024     -1.393      0.166      -0.081       0.014
# ==============================================================================
# Omnibus:                       24.692   Durbin-Watson:                   2.040
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                6.330
# Skew:                           0.042   Prob(JB):                       0.0422
# Kurtosis:                       1.983   Cond. No.                     4.65e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.34e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Optimal number of features : 1
# GridSearch 수행시간 :  2.8945868015289307
# 최적 하이퍼 파라미터 : {'C': 0.0, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV  0.405405  0.192308
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                 1.565e-07
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):               1.00
# Time:                        09:05:24   Log-Likelihood:                -182.86
# No. Observations:                 146   AIC:                             369.7
# Df Residuals:                     144   BIC:                             375.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9042      0.170      5.326      0.000       0.569       1.240
# 최우점식물군락    -8.305e-06      0.021     -0.000      1.000      -0.041       0.041
# ==============================================================================
# Omnibus:                     2638.348   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.026
# Skew:                           0.183   Prob(JB):                     0.000331
# Kurtosis:                       1.419   Cond. No.                         19.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GridSearch 수행시간 :  7.15196967124939
# 최적 하이퍼 파라미터 : {'C': 0.4, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV  0.566667  0.499125
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.120
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     1.495
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):             0.0847
# Time:                        09:05:31   Log-Likelihood:                -226.20
# No. Observations:                 240   AIC:                             494.4
# Df Residuals:                     219   BIC:                             567.5
# Df Model:                          20
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.2099      0.254      4.771      0.000       0.710       1.710
# 차선_수                -0.0101      0.121     -0.083      0.934      -0.249       0.229
# 등산객_이용빈도            -0.0474      0.062     -0.761      0.447      -0.170       0.075
# 폭(m)                 0.0795      0.064      1.233      0.219      -0.048       0.207
# 연장(m)               -0.1271      0.089     -1.425      0.156      -0.303       0.049
# 경사도                 -0.0333      0.049     -0.684      0.495      -0.129       0.063
# 주변 로드킬 빈도           -0.3713      0.440     -0.843      0.400      -1.239       0.496
# 산책로까지의 최단 거리(km)    -0.0172      0.084     -0.205      0.838      -0.183       0.148
# 농가까지의 거리(km)         0.1279      0.334      0.384      0.702      -0.529       0.785
# 도로 최고제한속도(km/h)      0.4669      0.223      2.091      0.038       0.027       0.907
# 주변 동물종 개수           -0.1721      0.102     -1.683      0.094      -0.374       0.029
# 주변동물 출현빈도            0.0304      0.030      1.005      0.316      -0.029       0.090
# 지형기호(2.3km)         -0.0242      0.020     -1.241      0.216      -0.063       0.014
# 하천거리(km)            -0.0441      0.061     -0.725      0.470      -0.164       0.076
# 등산로까지 최단거리(km)       0.0035      0.050      0.071      0.944      -0.094       0.101
# 유도울타리_연장_m          -0.0246      0.108     -0.228      0.820      -0.237       0.188
# 유도울타리_높이_m          -0.0159      0.110     -0.145      0.885      -0.232       0.200
# 교통량                  0.0392      0.079      0.495      0.621      -0.117       0.195
# 환경영향평가점수            -0.0237      0.041     -0.580      0.562      -0.104       0.057
# 건물까지거리(km)           0.4979      0.186      2.678      0.008       0.131       0.864
# 최우점식물군락             -0.0161      0.019     -0.864      0.389      -0.053       0.021
# ==============================================================================
# Omnibus:                        0.754   Durbin-Watson:                   1.931
# Prob(Omnibus):                  0.686   Jarque-Bera (JB):                0.541
# Skew:                           0.105   Prob(JB):                        0.763
# Kurtosis:                       3.101   Cond. No.                         110.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Optimal number of features : 4
# GridSearch 수행시간 :  4.602241277694702
# 최적 하이퍼 파라미터 : {'C': 0.7000000000000001, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV  0.583333  0.534181
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.069
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     4.345
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):            0.00208
# Time:                        09:05:39   Log-Likelihood:                -232.99
# No. Observations:                 240   AIC:                             476.0
# Df Residuals:                     235   BIC:                             493.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.9363      0.042     22.439      0.000       0.854       1.018
# 주변 로드킬 빈도          -0.2481      0.312     -0.796      0.427      -0.862       0.366
# 농가까지의 거리(km)        0.1575      0.300      0.525      0.600      -0.434       0.749
# 도로 최고제한속도(km/h)     0.3130      0.140      2.229      0.027       0.036       0.590
# 건물까지거리(km)          0.4594      0.162      2.839      0.005       0.141       0.778
# ==============================================================================
# Omnibus:                        2.379   Durbin-Watson:                   1.908
# Prob(Omnibus):                  0.304   Jarque-Bera (JB):                2.411
# Skew:                           0.204   Prob(JB):                        0.300
# Kurtosis:                       2.728   Cond. No.                         19.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GridSearch 수행시간 :  7.318042516708374
# 최적 하이퍼 파라미터 : {'C': 0.0, 'penalty': 'none', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV  0.566667  0.498105
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.156
# Model:                            OLS   Adj. R-squared:                  0.079
# Method:                 Least Squares   F-statistic:                     2.027
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):            0.00728
# Time:                        09:05:46   Log-Likelihood:                -221.17
# No. Observations:                 240   AIC:                             484.3
# Df Residuals:                     219   BIC:                             557.4
# Df Model:                          20
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.5589      0.245      6.374      0.000       1.077       2.041
# 차선_수                -0.0323      0.120     -0.270      0.787      -0.268       0.203
# 등산객_이용빈도            -0.0399      0.060     -0.661      0.509      -0.159       0.079
# 폭(m)                 0.0230      0.062      0.370      0.712      -0.100       0.146
# 연장(m)               -0.0265      0.093     -0.285      0.776      -0.210       0.157
# 경사도                 -0.0495      0.046     -1.072      0.285      -0.141       0.042
# 주변 로드킬 빈도           -1.2935      0.458     -2.823      0.005      -2.197      -0.390
# 산책로까지의 최단 거리(km)    -0.1114      0.081     -1.368      0.173      -0.272       0.049
# 농가까지의 거리(km)         0.7292      0.357      2.043      0.042       0.026       1.433
# 도로 최고제한속도(km/h)      0.1824      0.207      0.880      0.380      -0.226       0.591
# 주변 동물종 개수            0.0517      0.104      0.497      0.620      -0.153       0.257
# 주변동물 출현빈도           -0.0373      0.031     -1.219      0.224      -0.098       0.023
# 지형기호(2.3km)         -0.0205      0.019     -1.070      0.286      -0.058       0.017
# 하천거리(km)             0.0817      0.059      1.385      0.168      -0.035       0.198
# 등산로까지 최단거리(km)       0.0007      0.049      0.014      0.989      -0.096       0.098
# 유도울타리_연장_m           0.0457      0.108      0.422      0.674      -0.168       0.259
# 유도울타리_높이_m          -0.0555      0.107     -0.520      0.604      -0.266       0.155
# 교통량                  0.1964      0.074      2.667      0.008       0.051       0.342
# 환경영향평가점수            -0.0064      0.039     -0.165      0.869      -0.084       0.071
# 건물까지거리(km)           0.5731      0.180      3.177      0.002       0.218       0.929
# 최우점식물군락             -0.0456      0.018     -2.569      0.011      -0.081      -0.011
# ==============================================================================
# Omnibus:                        0.796   Durbin-Watson:                   2.034
# Prob(Omnibus):                  0.672   Jarque-Bera (JB):                0.536
# Skew:                           0.088   Prob(JB):                        0.765
# Kurtosis:                       3.151   Cond. No.                         121.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Optimal number of features : 3
# GridSearch 수행시간 :  3.3740196228027344
# 최적 하이퍼 파라미터 : {'C': 0.8, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV      0.65  0.612195
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     4.719
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):            0.00322
# Time:                        09:05:53   Log-Likelihood:                -234.56
# No. Observations:                 240   AIC:                             477.1
# Df Residuals:                     236   BIC:                             491.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.9506      0.042     22.664      0.000       0.868       1.033
# 주변 로드킬 빈도       -0.7955      0.302     -2.637      0.009      -1.390      -0.201
# 농가까지의 거리(km)     0.4306      0.321      1.340      0.182      -0.202       1.064
# 건물까지거리(km)       0.4262      0.165      2.584      0.010       0.101       0.751
# ==============================================================================
# Omnibus:                        3.599   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.165   Jarque-Bera (JB):                3.169
# Skew:                           0.197   Prob(JB):                        0.205
# Kurtosis:                       2.598   Cond. No.                         17.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GridSearch 수행시간 :  6.75040078163147
# 최적 하이퍼 파라미터 : {'C': 0.0, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV  0.405405  0.192308
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.145
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     1.120
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):              0.339
# Time:                        09:06:00   Log-Likelihood:                -171.47
# No. Observations:                 146   AIC:                             382.9
# Df Residuals:                     126   BIC:                             442.6
# Df Model:                          19
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.6816      0.408      4.125      0.000       0.875       2.488
# 차선_수                -0.0649      0.150     -0.432      0.667      -0.363       0.233
# 등산객_이용빈도            -0.0307      0.082     -0.375      0.709      -0.193       0.131
# 폭(m)                 0.1514      0.085      1.783      0.077      -0.017       0.319
# 연장(m)               -0.0507      0.090     -0.565      0.573      -0.228       0.127
# 경사도                 -0.0735      0.060     -1.234      0.219      -0.191       0.044
# 주변 로드킬 빈도        -4.586e-16   1.38e-16     -3.330      0.001   -7.31e-16   -1.86e-16
# 산책로까지의 최단 거리(km)    -0.0190      0.087     -0.217      0.828      -0.192       0.154
# 농가까지의 거리(km)         0.1341      0.083      1.614      0.109      -0.030       0.298
# 도로 최고제한속도(km/h)      0.0941      0.108      0.868      0.387      -0.120       0.309
# 주변 동물종 개수           -0.0135      0.166     -0.082      0.935      -0.341       0.314
# 주변동물 출현빈도           -0.0117      0.039     -0.304      0.762      -0.088       0.065
# 지형기호(2.3km)         -0.0217      0.026     -0.852      0.396      -0.072       0.029
# 하천거리(km)             0.0326      0.073      0.444      0.657      -0.112       0.178
# 등산로까지 최단거리(km)      -0.0334      0.082     -0.407      0.685      -0.196       0.129
# 유도울타리_연장_m           0.0433      0.177      0.244      0.808      -0.308       0.394
# 유도울타리_높이_m          -0.0172      0.166     -0.104      0.918      -0.345       0.311
# 교통량                  0.0335      0.108      0.311      0.757      -0.180       0.247
# 환경영향평가점수             0.0124      0.053      0.235      0.815      -0.092       0.117
# 건물까지거리(km)           0.2185      0.087      2.507      0.013       0.046       0.391
# 최우점식물군락             -0.0438      0.023     -1.890      0.061      -0.090       0.002
# ==============================================================================
# Omnibus:                       29.121   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                6.847
# Skew:                           0.066   Prob(JB):                       0.0326
# Kurtosis:                       1.947   Cond. No.                     3.03e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.71e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Optimal number of features : 1
# GridSearch 수행시간 :  2.209836721420288
# 최적 하이퍼 파라미터 : {'C': 0.0, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV  0.405405  0.192308
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.4551
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):              0.501
# Time:                        09:06:04   Log-Likelihood:                -182.63
# No. Observations:                 146   AIC:                             369.3
# Df Residuals:                     144   BIC:                             375.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0007      0.160      6.272      0.000       0.685       1.316
# 최우점식물군락       -0.0135      0.020     -0.675      0.501      -0.053       0.026
# ==============================================================================
# Omnibus:                     3002.790   Durbin-Watson:                   1.789
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               15.870
# Skew:                           0.187   Prob(JB):                     0.000358
# Kurtosis:                       1.429   Cond. No.                         18.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GridSearch 수행시간 :  7.3210673332214355
# 최적 하이퍼 파라미터 : {'C': 0.1, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV  0.633333  0.550792
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.151
# Model:                            OLS   Adj. R-squared:                  0.073
# Method:                 Least Squares   F-statistic:                     1.947
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):             0.0108
# Time:                        09:06:11   Log-Likelihood:                -221.92
# No. Observations:                 240   AIC:                             485.8
# Df Residuals:                     219   BIC:                             558.9
# Df Model:                          20
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.4383      0.240      5.995      0.000       0.965       1.911
# 차선_수                -0.2093      0.121     -1.729      0.085      -0.448       0.029
# 등산객_이용빈도            -0.0209      0.062     -0.336      0.737      -0.144       0.102
# 폭(m)                 0.0835      0.062      1.340      0.182      -0.039       0.206
# 연장(m)               -0.0014      0.090     -0.016      0.987      -0.178       0.176
# 경사도                 -0.0159      0.045     -0.355      0.723      -0.104       0.072
# 주변 로드킬 빈도           -0.6142      0.427     -1.437      0.152      -1.457       0.228
# 산책로까지의 최단 거리(km)    -0.0902      0.076     -1.187      0.237      -0.240       0.060
# 농가까지의 거리(km)         0.5591      0.323      1.734      0.084      -0.077       1.195
# 도로 최고제한속도(km/h)      0.4242      0.207      2.047      0.042       0.016       0.833
# 주변 동물종 개수            0.0625      0.098      0.636      0.526      -0.131       0.256
# 주변동물 출현빈도           -0.0353      0.029     -1.223      0.223      -0.092       0.022
# 지형기호(2.3km)         -0.0192      0.019     -0.991      0.323      -0.057       0.019
# 하천거리(km)             0.0238      0.062      0.383      0.702      -0.099       0.146
# 등산로까지 최단거리(km)      -0.0106      0.050     -0.210      0.834      -0.110       0.089
# 유도울타리_연장_m           0.1417      0.120      1.178      0.240      -0.095       0.379
# 유도울타리_높이_m          -0.1838      0.132     -1.396      0.164      -0.443       0.076
# 교통량                  0.1349      0.079      1.712      0.088      -0.020       0.290
# 환경영향평가점수             0.0099      0.039      0.250      0.803      -0.068       0.088
# 건물까지거리(km)           0.5575      0.182      3.065      0.002       0.199       0.916
# 최우점식물군락             -0.0295      0.017     -1.699      0.091      -0.064       0.005
# ==============================================================================
# Omnibus:                        0.693   Durbin-Watson:                   1.883
# Prob(Omnibus):                  0.707   Jarque-Bera (JB):                0.428
# Skew:                          -0.061   Prob(JB):                        0.807
# Kurtosis:                       3.167   Cond. No.                         110.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Optimal number of features : 4
# GridSearch 수행시간 :  3.4914333820343018
# 최적 하이퍼 파라미터 : {'C': 0.0, 'penalty': 'none', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV      0.65  0.597599
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.059
# Method:                 Least Squares   F-statistic:                     4.740
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):            0.00107
# Time:                        09:06:17   Log-Likelihood:                -232.24
# No. Observations:                 240   AIC:                             474.5
# Df Residuals:                     235   BIC:                             491.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.9388      0.042     22.571      0.000       0.857       1.021
# 주변 로드킬 빈도          -0.6729      0.299     -2.249      0.025      -1.262      -0.084
# 농가까지의 거리(km)        0.4349      0.299      1.454      0.147      -0.154       1.024
# 도로 최고제한속도(km/h)     0.1646      0.135      1.221      0.223      -0.101       0.430
# 건물까지거리(km)          0.4669      0.164      2.842      0.005       0.143       0.791
# ==============================================================================
# Omnibus:                        2.589   Durbin-Watson:                   1.919
# Prob(Omnibus):                  0.274   Jarque-Bera (JB):                2.496
# Skew:                           0.188   Prob(JB):                        0.287
# Kurtosis:                       2.671   Cond. No.                         18.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GridSearch 수행시간 :  6.703480243682861
# 최적 하이퍼 파라미터 : {'C': 0.1, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV  0.324324  0.308972
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.126
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                    0.9563
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):              0.516
# Time:                        09:06:23   Log-Likelihood:                -173.03
# No. Observations:                 146   AIC:                             386.1
# Df Residuals:                     126   BIC:                             445.7
# Df Model:                          19
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.3782      0.443      3.109      0.002       0.501       2.255
# 차선_수                -0.0653      0.162     -0.403      0.688      -0.386       0.255
# 등산객_이용빈도            -0.0933      0.080     -1.164      0.246      -0.252       0.065
# 폭(m)                 0.0972      0.092      1.061      0.291      -0.084       0.279
# 연장(m)               -0.0559      0.091     -0.614      0.540      -0.236       0.124
# 경사도                 -0.0349      0.063     -0.550      0.583      -0.160       0.091
# 주변 로드킬 빈도        -2.608e-18   6.78e-17     -0.038      0.969   -1.37e-16    1.32e-16
# 산책로까지의 최단 거리(km)    -0.0111      0.096     -0.116      0.908      -0.200       0.178
# 농가까지의 거리(km)         0.0953      0.080      1.189      0.237      -0.063       0.254
# 도로 최고제한속도(km/h)      0.0838      0.111      0.756      0.451      -0.136       0.303
# 주변 동물종 개수           -0.0371      0.172     -0.216      0.829      -0.377       0.303
# 주변동물 출현빈도           -0.0170      0.040     -0.422      0.674      -0.097       0.063
# 지형기호(2.3km)         -0.0041      0.027     -0.156      0.876      -0.057       0.048
# 하천거리(km)            -0.0022      0.075     -0.029      0.977      -0.150       0.146
# 등산로까지 최단거리(km)      -0.0368      0.087     -0.425      0.672      -0.208       0.135
# 유도울타리_연장_m          -0.1249      0.174     -0.718      0.474      -0.469       0.219
# 유도울타리_높이_m           0.0722      0.172      0.419      0.676      -0.269       0.413
# 교통량                  0.0764      0.115      0.664      0.508      -0.151       0.304
# 환경영향평가점수             0.0465      0.055      0.840      0.402      -0.063       0.156
# 건물까지거리(km)           0.2037      0.080      2.556      0.012       0.046       0.361
# 최우점식물군락             -0.0314      0.025     -1.246      0.215      -0.081       0.018
# ==============================================================================
# Omnibus:                       38.671   Durbin-Watson:                   2.209
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                7.763
# Skew:                           0.094   Prob(JB):                       0.0206
# Kurtosis:                       1.886   Cond. No.                     1.26e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.03e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Optimal number of features : 2
# GridSearch 수행시간 :  1.7783002853393555
# 최적 하이퍼 파라미터 : {'C': 0.30000000000000004, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV  0.405405  0.237797
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     3.990
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):             0.0206
# Time:                        09:06:27   Log-Likelihood:                -178.90
# No. Observations:                 146   AIC:                             363.8
# Df Residuals:                     143   BIC:                             372.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.8948      0.069     12.969      0.000       0.758       1.031
# 농가까지의 거리(km)     0.0734      0.070      1.053      0.294      -0.064       0.211
# 건물까지거리(km)       0.1541      0.071      2.157      0.033       0.013       0.295
# ==============================================================================
# Omnibus:                      296.039   Durbin-Watson:                   2.240
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               12.889
# Skew:                           0.131   Prob(JB):                      0.00159
# Kurtosis:                       1.568   Cond. No.                         1.39
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GridSearch 수행시간 :  6.772730588912964
# 최적 하이퍼 파라미터 : {'C': 0.0, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV  0.405405  0.192308
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.160
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     1.267
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):              0.217
# Time:                        09:06:34   Log-Likelihood:                -170.10
# No. Observations:                 146   AIC:                             380.2
# Df Residuals:                     126   BIC:                             439.9
# Df Model:                          19
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.7080      0.464      3.681      0.000       0.790       2.626
# 차선_수                -0.1445      0.162     -0.892      0.374      -0.465       0.176
# 등산객_이용빈도            -0.0020      0.079     -0.026      0.979      -0.159       0.155
# 폭(m)                 0.0966      0.082      1.179      0.241      -0.066       0.259
# 연장(m)               -0.1476      0.089     -1.650      0.101      -0.325       0.029
# 경사도                 -0.0825      0.068     -1.219      0.225      -0.216       0.051
# 주변 로드킬 빈도         3.031e-16   8.39e-17      3.615      0.000    1.37e-16    4.69e-16
# 산책로까지의 최단 거리(km)    -0.0604      0.085     -0.710      0.479      -0.229       0.108
# 농가까지의 거리(km)         0.1604      0.083      1.933      0.055      -0.004       0.325
# 도로 최고제한속도(km/h)      0.2113      0.119      1.774      0.078      -0.024       0.447
# 주변 동물종 개수           -0.2510      0.167     -1.507      0.134      -0.581       0.079
# 주변동물 출현빈도            0.0214      0.038      0.559      0.577      -0.054       0.097
# 지형기호(2.3km)         -0.0225      0.026     -0.858      0.392      -0.074       0.029
# 하천거리(km)             0.0041      0.072      0.057      0.955      -0.138       0.147
# 등산로까지 최단거리(km)       0.0070      0.083      0.085      0.933      -0.157       0.171
# 유도울타리_연장_m          -0.1260      0.174     -0.726      0.469      -0.469       0.217
# 유도울타리_높이_m           0.1103      0.170      0.650      0.517      -0.225       0.446
# 교통량                  0.1650      0.105      1.574      0.118      -0.042       0.372
# 환경영향평가점수            -0.0094      0.051     -0.183      0.855      -0.111       0.092
# 건물까지거리(km)           0.1460      0.081      1.793      0.075      -0.015       0.307
# 최우점식물군락             -0.0407      0.024     -1.682      0.095      -0.089       0.007
# ==============================================================================
# Omnibus:                       41.657   Durbin-Watson:                   2.097
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                7.793
# Skew:                           0.026   Prob(JB):                       0.0203
# Kurtosis:                       1.869   Cond. No.                     9.28e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.88e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Optimal number of features : 1
# GridSearch 수행시간 :  2.296595335006714
# 최적 하이퍼 파라미터 : {'C': 0.0, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV  0.405405  0.192308
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                   0.02848
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):              0.866
# Time:                        09:06:38   Log-Likelihood:                -182.85
# No. Observations:                 146   AIC:                             369.7
# Df Residuals:                     144   BIC:                             375.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9302      0.170      5.466      0.000       0.594       1.267
# 최우점식물군락       -0.0036      0.021     -0.169      0.866      -0.046       0.038
# ==============================================================================
# Omnibus:                     2672.384   Durbin-Watson:                   2.273
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.017
# Skew:                           0.185   Prob(JB):                     0.000333
# Kurtosis:                       1.420   Cond. No.                         19.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GridSearch 수행시간 :  6.673736572265625
# 최적 하이퍼 파라미터 : {'C': 0.0, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV  0.405405  0.192308
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.122
# Model:                            OLS   Adj. R-squared:                 -0.010
# ...
# 경사도                 -0.0746      0.045     -1.645      0.101      -0.164       0.015
# 주변 로드킬 빈도           -1.4103      0.445     -3.171      0.002      -2.287      -0.534
# 산책로까지의 최단 거리(km)    -0.1523      0.078     -1.940      0.054      -0.307       0.002
# 농가까지의 거리(km)         1.2319      0.344      3.582      0.000       0.554       1.910
# 도로 최고제한속도(km/h)      0.4880      0.209      2.330      0.021       0.075       0.901
# 주변 동물종 개수           -0.0574      0.098     -0.588      0.557      -0.250       0.135
# 주변동물 출현빈도           -0.0167      0.029     -0.577      0.564      -0.074       0.040
# 지형기호(2.3km)         -0.0071      0.020     -0.356      0.722      -0.046       0.032
# 하천거리(km)             0.0880      0.060      1.455      0.147      -0.031       0.207
# 등산로까지 최단거리(km)       0.0109      0.049      0.225      0.822      -0.085       0.107
# 유도울타리_연장_m          -0.0638      0.113     -0.563      0.574      -0.287       0.159
# 유도울타리_높이_m          -0.0165      0.112     -0.147      0.884      -0.238       0.205
# 교통량                  0.1031      0.075      1.382      0.168      -0.044       0.250
# 환경영향평가점수            -0.0334      0.040     -0.831      0.407      -0.113       0.046
# 건물까지거리(km)           0.3888      0.172      2.258      0.025       0.049       0.728
# 최우점식물군락             -0.0266      0.018     -1.448      0.149      -0.063       0.010
# ==============================================================================
# Omnibus:                        2.566   Durbin-Watson:                   2.121
# Prob(Omnibus):                  0.277   Jarque-Bera (JB):                2.651
# Skew:                           0.022   Prob(JB):                        0.266
# Kurtosis:                       3.513   Cond. No.                         118.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Optimal number of features : 2
# GridSearch 수행시간 :  2.856311082839966
# 최적 하이퍼 파라미터 : {'C': 0.0, 'penalty': 'none', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV  0.483333  0.381961
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.067
# Model:                            OLS   Adj. R-squared:                  0.059
# Method:                 Least Squares   F-statistic:                     8.444
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):           0.000287
# Time:                        09:07:03   Log-Likelihood:                -233.29
# No. Observations:                 240   AIC:                             472.6
# Df Residuals:                     237   BIC:                             483.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.9362      0.042     22.506      0.000       0.854       1.018
# 주변 로드킬 빈도       -1.0768      0.289     -3.730      0.000      -1.646      -0.508
# 농가까지의 거리(km)     1.1401      0.290      3.937      0.000       0.570       1.711
# ==============================================================================
# Omnibus:                        2.481   Durbin-Watson:                   2.200
# Prob(Omnibus):                  0.289   Jarque-Bera (JB):                2.464
# Skew:                           0.198   Prob(JB):                        0.292
# Kurtosis:                       2.700   Cond. No.                         14.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GridSearch 수행시간 :  6.630517959594727
# 최적 하이퍼 파라미터 : {'C': 0.0, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV  0.405405  0.192308
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.082
# Model:                            OLS   Adj. R-squared:                 -0.057
# Method:                 Least Squares   F-statistic:                    0.5889
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):              0.909
# Time:                        09:07:10   Log-Likelihood:                -176.65
# No. Observations:                 146   AIC:                             393.3
# Df Residuals:                     126   BIC:                             453.0
# Df Model:                          19
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.5026      0.418      3.598      0.000       0.676       2.329
# 차선_수                -0.0529      0.163     -0.325      0.746      -0.375       0.269
# 등산객_이용빈도            -0.0839      0.084     -0.996      0.321      -0.251       0.083
# 폭(m)                 0.0317      0.088      0.359      0.720      -0.143       0.206
# 연장(m)               -0.0484      0.094     -0.515      0.607      -0.234       0.137
# 경사도                 -0.0359      0.062     -0.582      0.562      -0.158       0.086
# 주변 로드킬 빈도        -3.268e-16   1.11e-16     -2.953      0.004   -5.46e-16   -1.08e-16
# 산책로까지의 최단 거리(km)    -0.0407      0.091     -0.448      0.655      -0.220       0.139
# 농가까지의 거리(km)         0.0812      0.082      0.985      0.327      -0.082       0.244
# 도로 최고제한속도(km/h)      0.1260      0.111      1.132      0.260      -0.094       0.346
# 주변 동물종 개수            0.0229      0.173      0.133      0.895      -0.319       0.365
# 주변동물 출현빈도           -0.0320      0.041     -0.787      0.433      -0.112       0.048
# 지형기호(2.3km)         -0.0199      0.026     -0.766      0.445      -0.071       0.031
# 하천거리(km)            -0.0056      0.080     -0.070      0.944      -0.163       0.152
# 등산로까지 최단거리(km)      -0.0299      0.081     -0.370      0.712      -0.190       0.130
# 유도울타리_연장_m          -0.0428      0.182     -0.235      0.814      -0.403       0.318
# 유도울타리_높이_m          -0.0258      0.186     -0.139      0.890      -0.393       0.342
# 교통량                  0.0898      0.113      0.792      0.430      -0.135       0.314
# 환경영향평가점수            -0.0043      0.054     -0.080      0.937      -0.111       0.102
# 건물까지거리(km)           0.1134      0.089      1.278      0.204      -0.062       0.289
# 최우점식물군락             -0.0205      0.025     -0.804      0.423      -0.071       0.030
# ==============================================================================
# Omnibus:                      120.035   Durbin-Watson:                   2.134
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               10.706
# Skew:                           0.046   Prob(JB):                      0.00473
# Kurtosis:                       1.677   Cond. No.                     9.29e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.81e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Optimal number of features : 1
# GridSearch 수행시간 :  2.315593957901001
# 최적 하이퍼 파라미터 : {'C': 0.0, 'penalty': 'none', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV  0.405405  0.192308
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                 0.0003641
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):              0.985
# Time:                        09:07:14   Log-Likelihood:                -182.86
# No. Observations:                 146   AIC:                             369.7
# Df Residuals:                     144   BIC:                             375.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9071      0.171      5.300      0.000       0.569       1.245
# 최우점식물군락       -0.0004      0.022     -0.019      0.985      -0.043       0.042
# ==============================================================================
# Omnibus:                     2642.346   Durbin-Watson:                   2.150
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.026
# Skew:                           0.184   Prob(JB):                     0.000331
# Kurtosis:                       1.419   Cond. No.                         19.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GridSearch 수행시간 :  7.215676784515381
# 최적 하이퍼 파라미터 : {'C': 0.0, 'penalty': 'none', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV      0.65  0.579249
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.163
# Model:                            OLS   Adj. R-squared:                  0.087
# Method:                 Least Squares   F-statistic:                     2.133
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):            0.00426
# Time:                        09:07:21   Log-Likelihood:                -220.19
# No. Observations:                 240   AIC:                             482.4
# Df Residuals:                     219   BIC:                             555.5
# Df Model:                          20
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.2849      0.241      5.326      0.000       0.809       1.760
# 차선_수                -0.1582      0.123     -1.288      0.199      -0.400       0.084
# 등산객_이용빈도            -0.0356      0.060     -0.592      0.554      -0.154       0.083
# 폭(m)                 0.0986      0.062      1.583      0.115      -0.024       0.221
# 연장(m)               -0.1100      0.089     -1.234      0.218      -0.286       0.066
# 경사도                 -0.0382      0.045     -0.854      0.394      -0.126       0.050
# 주변 로드킬 빈도           -0.7917      0.458     -1.730      0.085      -1.694       0.110
# 산책로까지의 최단 거리(km)    -0.1548      0.078     -1.979      0.049      -0.309      -0.001
# 농가까지의 거리(km)         0.6048      0.346      1.749      0.082      -0.077       1.286
# 도로 최고제한속도(km/h)      0.4477      0.202      2.218      0.028       0.050       0.845
# 주변 동물종 개수            0.0315      0.096      0.329      0.743      -0.157       0.220
# 주변동물 출현빈도           -0.0308      0.028     -1.085      0.279      -0.087       0.025
# 지형기호(2.3km)          0.0081      0.020      0.412      0.681      -0.031       0.047
# 하천거리(km)             0.0638      0.060      1.063      0.289      -0.055       0.182
# 등산로까지 최단거리(km)      -0.0230      0.053     -0.432      0.666      -0.128       0.082
# 유도울타리_연장_m          -0.0008      0.103     -0.008      0.994      -0.204       0.202
# 유도울타리_높이_m          -0.0432      0.103     -0.421      0.674      -0.245       0.159
# 교통량                  0.1584      0.076      2.074      0.039       0.008       0.309
# 환경영향평가점수             0.0265      0.040      0.669      0.504      -0.052       0.105
# 건물까지거리(km)           0.6089      0.174      3.491      0.001       0.265       0.953
# 최우점식물군락             -0.0070      0.018     -0.399      0.691      -0.042       0.028
# ==============================================================================
# Omnibus:                        0.755   Durbin-Watson:                   2.086
# Prob(Omnibus):                  0.685   Jarque-Bera (JB):                0.478
# Skew:                           0.060   Prob(JB):                        0.787
# Kurtosis:                       3.183   Cond. No.                         121.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Optimal number of features : 3
# GridSearch 수행시간 :  3.4281153678894043
# 최적 하이퍼 파라미터 : {'C': 0.0, 'penalty': 'none', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV       0.6  0.548084
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.077
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     6.565
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):           0.000279
# Time:                        09:07:28   Log-Likelihood:                -231.93
# No. Observations:                 240   AIC:                             471.9
# Df Residuals:                     236   BIC:                             485.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.9503      0.041     22.917      0.000       0.869       1.032
# 주변 로드킬 빈도       -0.9449      0.297     -3.179      0.002      -1.530      -0.359
# 농가까지의 거리(km)     0.5096      0.316      1.613      0.108      -0.113       1.132
# 건물까지거리(km)       0.5007      0.162      3.085      0.002       0.181       0.820
# ==============================================================================
# Omnibus:                        2.852   Durbin-Watson:                   2.141
# Prob(Omnibus):                  0.240   Jarque-Bera (JB):                2.797
# Skew:                           0.213   Prob(JB):                        0.247
# Kurtosis:                       2.687   Cond. No.                         17.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # 터널형

# %%
for case in tunnel_list :
  df = pd.read_csv(case, encoding='cp949')
  name = case.split('/')[-1].split('.')[0]
  df = preprocess_df(df, drop_col=drop_col, labeling_col=onehot_col, scaling_col=scaling_col, scaling_func=StandardScaler)
 
  # x, y
  x=df.drop('생태통로_효율성', axis=1)
  y=df['생태통로_효율성']

  # train & test set
  train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.2, stratify=df['생태통로_효율성'])

  # logistic regression
  lr_clf =logistic_regression(train_x, train_y, optimizing=True)
  pred_y = lr_clf.predict(test_x)

  # evaluation
  evalutation_lf(test_y, pred_y)

  # summary
  summary_lr(train_x, train_y)

  # rfecv
  selected_x = rfecv_lr(lr_clf, train_x, train_y)

  # RFECV로 선택된 변수로 logistic regression
  lr_clf = logistic_regression(train_x[selected_x], train_y, optimizing=True)
  pred_y = lr_clf.predict(test_x[selected_x])

  # evaluation
  evalutation_lf(test_y, pred_y)

  # summary
  summary_lr(train_x[selected_x], train_y)
# Out:
# GridSearch 수행시간 :  6.430907249450684
# 최적 하이퍼 파라미터 : {'C': 0.7000000000000001, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV      0.52  0.398551
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.398
# Model:                            OLS   Adj. R-squared:                  0.229
# Method:                 Least Squares   F-statistic:                     2.356
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):            0.00363
# Time:                        09:07:34   Log-Likelihood:                -102.59
# No. Observations:                  97   AIC:                             249.2
# Df Residuals:                      75   BIC:                             305.8
# Df Model:                          21
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -0.6758      1.489     -0.454      0.651      -3.642       2.290
# 차선_수                 0.0528      0.345      0.153      0.879      -0.634       0.740
# 등산객_이용빈도            -0.4716      0.115     -4.093      0.000      -0.701      -0.242
# 폭(m)                -0.2569      0.213     -1.204      0.232      -0.682       0.168
# 연장(m)                0.0382      0.134      0.284      0.777      -0.229       0.306
# 높이(m)                0.4280      0.478      0.895      0.374      -0.525       1.381
# 개방도                  0.5204      0.637      0.816      0.417      -0.749       1.790
# 경사도                  0.0657      0.058      1.129      0.262      -0.050       0.182
# 주변 로드킬 빈도         1.613e-16    3.4e-16      0.475      0.636   -5.16e-16    8.39e-16
# 산책로까지의 최단 거리(km)    -0.1575      0.113     -1.395      0.167      -0.382       0.067
# 농가까지의 거리(km)        -0.0198      0.117     -0.168      0.867      -0.254       0.214
# 도로 최고제한속도(km/h)      0.0994      0.224      0.444      0.658      -0.347       0.545
# 주변 동물종 개수            0.3274      0.226      1.449      0.151      -0.123       0.777
# 주변동물 출현빈도           -0.0978      0.044     -2.223      0.029      -0.185      -0.010
# 지형기호(2.3km)          0.0941      0.037      2.529      0.014       0.020       0.168
# 하천거리(km)             0.0263      0.097      0.272      0.787      -0.167       0.219
# 등산로까지 최단거리(km)       0.1457      0.091      1.593      0.115      -0.036       0.328
# 유도울타리_연장_m          -0.0030      0.172     -0.018      0.986      -0.345       0.339
# 유도울타리_높이_m          -0.1497      0.167     -0.895      0.374      -0.483       0.184
# 교통량                 -0.2369      0.135     -1.752      0.084      -0.506       0.032
# 환경영향평가점수             0.0608      0.068      0.894      0.374      -0.075       0.196
# 건물까지거리(km)           0.1076      0.110      0.978      0.331      -0.112       0.327
# 최우점식물군락             -0.0093      0.022     -0.430      0.668      -0.052       0.034
# ==============================================================================
# Omnibus:                        8.745   Durbin-Watson:                   1.896
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                3.789
# Skew:                           0.202   Prob(JB):                        0.150
# Kurtosis:                       2.120   Cond. No.                     1.68e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.9e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Optimal number of features : 1
# GridSearch 수행시간 :  1.8918263912200928
# 최적 하이퍼 파라미터 : {'C': 0.0, 'penalty': 'none', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV      0.56  0.412698
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.131
# Model:                            OLS   Adj. R-squared:                  0.122
# Method:                 Least Squares   F-statistic:                     14.30
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):           0.000273
# Time:                        09:07:39   Log-Likelihood:                -120.37
# No. Observations:                  97   AIC:                             244.7
# Df Residuals:                      95   BIC:                             249.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1837      0.113     10.496      0.000       0.960       1.408
# 등산객_이용빈도      -0.3973      0.105     -3.781      0.000      -0.606      -0.189
# ==============================================================================
# Omnibus:                       60.740   Durbin-Watson:                   1.943
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                7.136
# Skew:                           0.002   Prob(JB):                       0.0282
# Kurtosis:                       1.671   Cond. No.                         2.17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GridSearch 수행시간 :  8.61005187034607
# 최적 하이퍼 파라미터 : {'C': 0.4, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV     0.675  0.592716
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.536
# Model:                            OLS   Adj. R-squared:                  0.460
# Method:                 Least Squares   F-statistic:                     7.034
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):           1.12e-13
# Time:                        09:07:48   Log-Likelihood:                -108.08
# No. Observations:                 157   AIC:                             262.2
# Df Residuals:                     134   BIC:                             332.5
# Df Model:                          22
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -0.4538      0.951     -0.477      0.634      -2.335       1.427
# 차선_수                -0.2705      0.166     -1.633      0.105      -0.598       0.057
# 등산객_이용빈도            -0.5392      0.075     -7.184      0.000      -0.688      -0.391
# 폭(m)                -0.8266      0.393     -2.104      0.037      -1.604      -0.050
# 연장(m)                0.0934      0.174      0.537      0.592      -0.251       0.437
# 높이(m)                0.6030      0.347      1.735      0.085      -0.084       1.290
# 개방도                  0.8852      0.463      1.912      0.058      -0.031       1.801
# 경사도                  0.0052      0.039      0.135      0.893      -0.072       0.082
# 주변 로드킬 빈도           -0.3596      0.523     -0.688      0.493      -1.394       0.675
# 산책로까지의 최단 거리(km)    -0.2718      0.077     -3.513      0.001      -0.425      -0.119
# 농가까지의 거리(km)         0.9586      0.371      2.584      0.011       0.225       1.692
# 도로 최고제한속도(km/h)      0.6272      0.269      2.327      0.021       0.094       1.160
# 주변 동물종 개수            0.1951      0.109      1.782      0.077      -0.021       0.412
# 주변동물 출현빈도           -0.0791      0.026     -3.035      0.003      -0.131      -0.028
# 지형기호(2.3km)          0.1204      0.025      4.789      0.000       0.071       0.170
# 하천거리(km)             0.1218      0.056      2.171      0.032       0.011       0.233
# 등산로까지 최단거리(km)       0.1135      0.049      2.334      0.021       0.017       0.210
# 유도울타리_연장_m          -0.0457      0.096     -0.475      0.635      -0.236       0.145
# 유도울타리_높이_m        6.021e-05      0.092      0.001      0.999      -0.182       0.182
# 교통량                 -0.1725      0.078     -2.215      0.028      -0.327      -0.018
# 환경영향평가점수             0.0302      0.042      0.724      0.470      -0.052       0.113
# 건물까지거리(km)          -0.2382      0.165     -1.445      0.151      -0.564       0.088
# 최우점식물군락             -0.0308      0.015     -2.113      0.036      -0.060      -0.002
# ==============================================================================
# Omnibus:                        6.288   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.043   Jarque-Bera (JB):               10.236
# Skew:                           0.042   Prob(JB):                      0.00599
# Kurtosis:                       4.248   Cond. No.                         291.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Optimal number of features : 20
# GridSearch 수행시간 :  6.730531930923462
# 최적 하이퍼 파라미터 : {'C': 0.8, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy  F1Score
# 0  Logistic Regression RFECV     0.675  0.59156
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.520
# Model:                            OLS   Adj. R-squared:                  0.450
# Method:                 Least Squares   F-statistic:                     7.371
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):           1.06e-13
# Time:                        09:07:57   Log-Likelihood:                -110.71
# No. Observations:                 157   AIC:                             263.4
# Df Residuals:                     136   BIC:                             327.6
# Df Model:                          20
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -0.5765      0.954     -0.604      0.547      -2.462       1.309
# 차선_수                -0.2578      0.167     -1.544      0.125      -0.588       0.072
# 등산객_이용빈도            -0.5577      0.075     -7.437      0.000      -0.706      -0.409
# 폭(m)                -0.7644      0.395     -1.933      0.055      -1.546       0.018
# 연장(m)                0.1058      0.168      0.628      0.531      -0.227       0.439
# 높이(m)                0.5832      0.350      1.665      0.098      -0.109       1.276
# 개방도                  0.8226      0.466      1.767      0.079      -0.098       1.743
# 경사도                  0.0177      0.038      0.463      0.644      -0.058       0.093
# 주변 로드킬 빈도           -0.2135      0.497     -0.429      0.668      -1.197       0.770
# 산책로까지의 최단 거리(km)    -0.2848      0.077     -3.703      0.000      -0.437      -0.133
# 농가까지의 거리(km)         0.9899      0.374      2.646      0.009       0.250       1.730
# 도로 최고제한속도(km/h)      0.5613      0.267      2.100      0.038       0.033       1.090
# 주변 동물종 개수            0.1825      0.110      1.658      0.100      -0.035       0.400
# 주변동물 출현빈도           -0.0803      0.026     -3.052      0.003      -0.132      -0.028
# 지형기호(2.3km)          0.1074      0.025      4.370      0.000       0.059       0.156
# 하천거리(km)             0.1082      0.056      1.933      0.055      -0.003       0.219
# 등산로까지 최단거리(km)       0.1214      0.049      2.481      0.014       0.025       0.218
# 유도울타리_연장_m          -0.0206      0.079     -0.260      0.795      -0.177       0.136
# 교통량                 -0.1350      0.074     -1.830      0.069      -0.281       0.011
# 환경영향평가점수             0.0344      0.042      0.829      0.408      -0.048       0.116
# 건물까지거리(km)          -0.2381      0.166     -1.431      0.155      -0.567       0.091
# ==============================================================================
# Omnibus:                        7.309   Durbin-Watson:                   2.055
# Prob(Omnibus):                  0.026   Jarque-Bera (JB):               13.085
# Skew:                          -0.056   Prob(JB):                      0.00144
# Kurtosis:                       4.410   Cond. No.                         169.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GridSearch 수행시간 :  6.842145919799805
# 최적 하이퍼 파라미터 : {'C': 0.6000000000000001, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV       0.6  0.491917
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.433
# Model:                            OLS   Adj. R-squared:                  0.340
# Method:                 Least Squares   F-statistic:                     4.651
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):           9.70e-09
# Time:                        09:08:04   Log-Likelihood:                -123.81
# No. Observations:                 157   AIC:                             293.6
# Df Residuals:                     134   BIC:                             363.9
# Df Model:                          22
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -0.1197      1.227     -0.098      0.922      -2.547       2.307
# 차선_수                 0.0385      0.206      0.187      0.852      -0.369       0.446
# 등산객_이용빈도            -0.5035      0.086     -5.858      0.000      -0.673      -0.333
# 폭(m)                -0.5451      0.484     -1.126      0.262      -1.502       0.412
# 연장(m)                0.1626      0.262      0.620      0.537      -0.356       0.682
# 높이(m)                0.1192      0.627      0.190      0.849      -1.120       1.358
# 개방도                  0.9119      0.779      1.171      0.244      -0.628       2.452
# 경사도                  0.0769      0.045      1.721      0.088      -0.011       0.165
# 주변 로드킬 빈도           -0.2795      0.710     -0.394      0.695      -1.684       1.125
# 산책로까지의 최단 거리(km)    -0.2225      0.092     -2.420      0.017      -0.404      -0.041
# 농가까지의 거리(km)         0.1680      0.362      0.464      0.643      -0.548       0.884
# 도로 최고제한속도(km/h)      0.2474      0.315      0.786      0.433      -0.375       0.870
# 주변 동물종 개수            0.2175      0.125      1.740      0.084      -0.030       0.465
# 주변동물 출현빈도           -0.0846      0.029     -2.897      0.004      -0.142      -0.027
# 지형기호(2.3km)          0.0813      0.029      2.787      0.006       0.024       0.139
# 하천거리(km)             0.0274      0.079      0.348      0.728      -0.128       0.183
# 등산로까지 최단거리(km)       0.1473      0.060      2.459      0.015       0.029       0.266
# 유도울타리_연장_m           0.0332      0.097      0.341      0.733      -0.159       0.225
# 유도울타리_높이_m          -0.1011      0.099     -1.022      0.309      -0.297       0.095
# 교통량                 -0.1934      0.092     -2.098      0.038      -0.376      -0.011
# 환경영향평가점수             0.0574      0.048      1.194      0.235      -0.038       0.152
# 건물까지거리(km)           0.2742      0.163      1.684      0.095      -0.048       0.596
# 최우점식물군락              0.0119      0.017      0.700      0.485      -0.022       0.046
# ==============================================================================
# Omnibus:                        6.071   Durbin-Watson:                   2.123
# Prob(Omnibus):                  0.048   Jarque-Bera (JB):                8.607
# Skew:                          -0.160   Prob(JB):                       0.0135
# Kurtosis:                       4.101   Cond. No.                         345.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Optimal number of features : 6
# GridSearch 수행시간 :  4.382641553878784
# 최적 하이퍼 파라미터 : {'C': 0.8, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV       0.7  0.687037
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.237
# Model:                            OLS   Adj. R-squared:                  0.206
# Method:                 Least Squares   F-statistic:                     7.752
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):           2.84e-07
# Time:                        09:08:11   Log-Likelihood:                -147.14
# No. Observations:                 157   AIC:                             308.3
# Df Residuals:                     150   BIC:                             329.7
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               1.0477      0.233      4.502      0.000       0.588       1.508
# 등산객_이용빈도           -0.4954      0.082     -6.061      0.000      -0.657      -0.334
# 연장(m)              -0.0759      0.168     -0.452      0.652      -0.408       0.256
# 개방도                 0.3108      0.243      1.277      0.204      -0.170       0.792
# 농가까지의 거리(km)        0.3631      0.171      2.122      0.035       0.025       0.701
# 도로 최고제한속도(km/h)     0.3553      0.146      2.437      0.016       0.067       0.643
# 주변 동물종 개수          -0.0964      0.053     -1.814      0.072      -0.201       0.009
# ==============================================================================
# Omnibus:                        1.174   Durbin-Watson:                   2.064
# Prob(Omnibus):                  0.556   Jarque-Bera (JB):                0.778
# Skew:                          -0.095   Prob(JB):                        0.678
# Kurtosis:                       3.287   Cond. No.                         12.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GridSearch 수행시간 :  6.785912275314331
# 최적 하이퍼 파라미터 : {'C': 0.1, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV     0.775  0.712753
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.412
# Model:                            OLS   Adj. R-squared:                  0.316
# Method:                 Least Squares   F-statistic:                     4.273
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):           6.68e-08
# Time:                        09:08:18   Log-Likelihood:                -126.62
# No. Observations:                 157   AIC:                             299.2
# Df Residuals:                     134   BIC:                             369.5
# Df Model:                          22
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.1551      0.853      0.182      0.856      -1.533       1.843
# 차선_수                -0.2596      0.196     -1.325      0.187      -0.647       0.128
# 등산객_이용빈도            -0.4886      0.085     -5.780      0.000      -0.656      -0.321
# 폭(m)                -0.4903      0.365     -1.342      0.182      -1.213       0.232
# 연장(m)                0.1339      0.190      0.706      0.482      -0.241       0.509
# 높이(m)                0.3411      0.343      0.993      0.322      -0.338       1.020
# 개방도                  0.5496      0.464      1.185      0.238      -0.368       1.467
# 경사도                  0.0364      0.046      0.787      0.432      -0.055       0.128
# 주변 로드킬 빈도            0.2096      0.612      0.343      0.732      -1.001       1.420
# 산책로까지의 최단 거리(km)    -0.3005      0.093     -3.247      0.001      -0.483      -0.117
# 농가까지의 거리(km)         0.1789      0.358      0.500      0.618      -0.528       0.886
# 도로 최고제한속도(km/h)      0.5773      0.312      1.849      0.067      -0.040       1.195
# 주변 동물종 개수            0.2657      0.122      2.179      0.031       0.025       0.507
# 주변동물 출현빈도           -0.0839      0.028     -2.951      0.004      -0.140      -0.028
# 지형기호(2.3km)          0.0817      0.028      2.914      0.004       0.026       0.137
# 하천거리(km)            -0.0164      0.069     -0.239      0.812      -0.152       0.120
# 등산로까지 최단거리(km)       0.0907      0.055      1.648      0.102      -0.018       0.199
# 유도울타리_연장_m           0.0365      0.104      0.350      0.727      -0.170       0.243
# 유도울타리_높이_m          -0.1854      0.108     -1.712      0.089      -0.400       0.029
# 교통량                 -0.0716      0.092     -0.779      0.437      -0.253       0.110
# 환경영향평가점수             0.0503      0.048      1.045      0.298      -0.045       0.146
# 건물까지거리(km)           0.2693      0.157      1.712      0.089      -0.042       0.580
# 최우점식물군락             -0.0064      0.016     -0.399      0.691      -0.038       0.026
# ==============================================================================
# Omnibus:                        4.631   Durbin-Watson:                   1.903
# Prob(Omnibus):                  0.099   Jarque-Bera (JB):                6.308
# Skew:                           0.006   Prob(JB):                       0.0427
# Kurtosis:                       3.982   Cond. No.                         231.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Optimal number of features : 5
# GridSearch 수행시간 :  3.659764051437378
# 최적 하이퍼 파라미터 : {'C': 0.30000000000000004, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV     0.725  0.658382
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.246
# Model:                            OLS   Adj. R-squared:                  0.221
# Method:                 Least Squares   F-statistic:                     9.863
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):           3.55e-08
# Time:                        09:08:24   Log-Likelihood:                -146.16
# No. Observations:                 157   AIC:                             304.3
# Df Residuals:                     151   BIC:                             322.7
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.2893      0.082     15.801      0.000       1.128       1.451
# 등산객_이용빈도            -0.4523      0.080     -5.682      0.000      -0.610      -0.295
# 주변 로드킬 빈도           -0.7859      0.285     -2.762      0.006      -1.348      -0.224
# 산책로까지의 최단 거리(km)    -0.3031      0.077     -3.959      0.000      -0.454      -0.152
# 농가까지의 거리(km)         0.7828      0.272      2.878      0.005       0.245       1.320
# 도로 최고제한속도(km/h)      0.0806      0.139      0.579      0.563      -0.194       0.355
# ==============================================================================
# Omnibus:                        1.147   Durbin-Watson:                   1.894
# Prob(Omnibus):                  0.564   Jarque-Bera (JB):                0.757
# Skew:                          -0.051   Prob(JB):                        0.685
# Kurtosis:                       3.324   Cond. No.                         14.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GridSearch 수행시간 :  6.488073110580444
# 최적 하이퍼 파라미터 : {'C': 0.9, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV      0.52  0.459091
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.457
# Model:                            OLS   Adj. R-squared:                  0.305
# Method:                 Least Squares   F-statistic:                     3.010
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):           0.000245
# Time:                        09:08:31   Log-Likelihood:                -97.517
# No. Observations:                  97   AIC:                             239.0
# Df Residuals:                      75   BIC:                             295.7
# Df Model:                          21
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.1420      1.850      0.617      0.539      -2.543       4.827
# 차선_수                -0.1816      0.241     -0.754      0.453      -0.661       0.298
# 등산객_이용빈도            -0.6006      0.113     -5.299      0.000      -0.826      -0.375
# 폭(m)                -0.1689      0.226     -0.747      0.457      -0.619       0.281
# 연장(m)                0.0433      0.129      0.336      0.738      -0.213       0.300
# 높이(m)               -0.2822      0.704     -0.401      0.690      -1.684       1.120
# 개방도                  1.1298      0.873      1.294      0.200      -0.610       2.870
# 경사도                  0.0775      0.052      1.481      0.143      -0.027       0.182
# 주변 로드킬 빈도        -3.782e-15   5.72e-15     -0.661      0.511   -1.52e-14    7.61e-15
# 산책로까지의 최단 거리(km)    -0.2762      0.106     -2.612      0.011      -0.487      -0.066
# 농가까지의 거리(km)         0.0686      0.114      0.602      0.549      -0.158       0.296
# 도로 최고제한속도(km/h)      0.1555      0.190      0.820      0.415      -0.222       0.533
# 주변 동물종 개수            0.4069      0.223      1.823      0.072      -0.038       0.852
# 주변동물 출현빈도           -0.0997      0.044     -2.269      0.026      -0.187      -0.012
# 지형기호(2.3km)          0.0916      0.038      2.385      0.020       0.015       0.168
# 하천거리(km)             0.0584      0.101      0.579      0.564      -0.142       0.259
# 등산로까지 최단거리(km)       0.1971      0.089      2.207      0.030       0.019       0.375
# 유도울타리_연장_m           0.0540      0.153      0.354      0.725      -0.250       0.358
# 유도울타리_높이_m          -0.2222      0.158     -1.408      0.163      -0.537       0.092
# 교통량                 -0.0508      0.116     -0.437      0.663      -0.282       0.181
# 환경영향평가점수             0.0555      0.061      0.910      0.366      -0.066       0.177
# 건물까지거리(km)           0.1216      0.111      1.100      0.275      -0.099       0.342
# 최우점식물군락             -0.0055      0.023     -0.246      0.807      -0.050       0.039
# ==============================================================================
# Omnibus:                        1.962   Durbin-Watson:                   2.075
# Prob(Omnibus):                  0.375   Jarque-Bera (JB):                1.550
# Skew:                          -0.132   Prob(JB):                        0.461
# Kurtosis:                       2.440   Cond. No.                     1.82e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.86e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Optimal number of features : 1
# GridSearch 수행시간 :  1.8133985996246338
# 최적 하이퍼 파라미터 : {'C': 0.0, 'penalty': 'none', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV      0.52  0.390013
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.187
# Model:                            OLS   Adj. R-squared:                  0.178
# Method:                 Least Squares   F-statistic:                     21.81
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):           9.88e-06
# Time:                        09:08:35   Log-Likelihood:                -117.14
# No. Observations:                  97   AIC:                             238.3
# Df Residuals:                      95   BIC:                             243.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.2088      0.105     11.490      0.000       1.000       1.418
# 등산객_이용빈도      -0.4876      0.104     -4.670      0.000      -0.695      -0.280
# ==============================================================================
# Omnibus:                       81.048   Durbin-Watson:                   2.221
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                8.145
# Skew:                          -0.170   Prob(JB):                       0.0170
# Kurtosis:                       1.622   Cond. No.                         2.04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GridSearch 수행시간 :  7.443305969238281
# 최적 하이퍼 파라미터 : {'C': 0.30000000000000004, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV     0.725  0.709259
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.417
# Model:                            OLS   Adj. R-squared:                  0.322
# Method:                 Least Squares   F-statistic:                     4.366
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):           4.15e-08
# Time:                        09:08:43   Log-Likelihood:                -125.92
# No. Observations:                 157   AIC:                             297.8
# Df Residuals:                     134   BIC:                             368.1
# Df Model:                          22
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.7694      0.982      0.784      0.435      -1.173       2.712
# 차선_수                -0.3645      0.212     -1.719      0.088      -0.784       0.055
# 등산객_이용빈도            -0.4481      0.092     -4.890      0.000      -0.629      -0.267
# 폭(m)                -0.5064      0.431     -1.176      0.242      -1.358       0.345
# 연장(m)                0.1468      0.252      0.582      0.562      -0.352       0.646
# 높이(m)                0.0658      0.366      0.180      0.858      -0.659       0.790
# 개방도                  0.7371      0.549      1.343      0.182      -0.348       1.823
# 경사도                  0.0192      0.046      0.421      0.674      -0.071       0.109
# 주변 로드킬 빈도            0.4690      0.598      0.785      0.434      -0.713       1.651
# 산책로까지의 최단 거리(km)    -0.2990      0.088     -3.405      0.001      -0.473      -0.125
# 농가까지의 거리(km)         0.1205      0.405      0.297      0.767      -0.681       0.922
# 도로 최고제한속도(km/h)      0.9007      0.347      2.599      0.010       0.215       1.586
# 주변 동물종 개수            0.2423      0.125      1.936      0.055      -0.005       0.490
# 주변동물 출현빈도           -0.0797      0.030     -2.672      0.008      -0.139      -0.021
# 지형기호(2.3km)          0.0918      0.034      2.723      0.007       0.025       0.159
# 하천거리(km)             0.1387      0.069      2.005      0.047       0.002       0.276
# 등산로까지 최단거리(km)       0.0458      0.060      0.765      0.445      -0.073       0.164
# 유도울타리_연장_m           0.0728      0.111      0.658      0.512      -0.146       0.292
# 유도울타리_높이_m          -0.2463      0.120     -2.055      0.042      -0.483      -0.009
# 교통량                 -0.1419      0.112     -1.264      0.209      -0.364       0.080
# 환경영향평가점수            -0.0024      0.052     -0.046      0.964      -0.105       0.100
# 건물까지거리(km)           0.0900      0.174      0.516      0.606      -0.255       0.435
# 최우점식물군락             -0.0040      0.016     -0.247      0.805      -0.036       0.028
# ==============================================================================
# Omnibus:                        5.442   Durbin-Watson:                   2.163
# Prob(Omnibus):                  0.066   Jarque-Bera (JB):                6.094
# Skew:                           0.251   Prob(JB):                       0.0475
# Kurtosis:                       3.825   Cond. No.                         269.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Optimal number of features : 9
# GridSearch 수행시간 :  5.42715859413147
# 최적 하이퍼 파라미터 : {'C': 0.2, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV     0.625  0.597267
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.290
# Model:                            OLS   Adj. R-squared:                  0.247
# Method:                 Least Squares   F-statistic:                     6.682
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):           5.45e-08
# Time:                        09:08:51   Log-Likelihood:                -141.42
# No. Observations:                 157   AIC:                             302.8
# Df Residuals:                     147   BIC:                             333.4
# Df Model:                           9
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.6353      0.157     10.391      0.000       1.324       1.946
# 차선_수                -0.4615      0.180     -2.565      0.011      -0.817      -0.106
# 등산객_이용빈도            -0.4520      0.080     -5.626      0.000      -0.611      -0.293
# 연장(m)               -0.0968      0.147     -0.661      0.510      -0.387       0.193
# 주변 로드킬 빈도           -0.0702      0.398     -0.176      0.860      -0.858       0.717
# 산책로까지의 최단 거리(km)    -0.2408      0.079     -3.052      0.003      -0.397      -0.085
# 농가까지의 거리(km)         0.5518      0.366      1.508      0.134      -0.171       1.275
# 도로 최고제한속도(km/h)      0.6297      0.293      2.150      0.033       0.051       1.208
# 유도울타리_연장_m          -0.0041      0.091     -0.045      0.964      -0.185       0.176
# 건물까지거리(km)           0.0725      0.173      0.420      0.675      -0.269       0.414
# ==============================================================================
# Omnibus:                        2.459   Durbin-Watson:                   2.058
# Prob(Omnibus):                  0.292   Jarque-Bera (JB):                2.394
# Skew:                          -0.010   Prob(JB):                        0.302
# Kurtosis:                       3.605   Cond. No.                         24.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GridSearch 수행시간 :  6.7580649852752686
# 최적 하이퍼 파라미터 : {'C': 0.30000000000000004, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV       0.8  0.775744
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.379
# Model:                            OLS   Adj. R-squared:                  0.277
# Method:                 Least Squares   F-statistic:                     3.718
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):           1.20e-06
# Time:                        09:08:58   Log-Likelihood:                -130.94
# No. Observations:                 157   AIC:                             307.9
# Df Residuals:                     134   BIC:                             378.2
# Df Model:                          22
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.4862      1.053      1.411      0.160      -0.597       3.569
# 차선_수                -0.3415      0.210     -1.630      0.106      -0.756       0.073
# 등산객_이용빈도            -0.4512      0.090     -5.005      0.000      -0.630      -0.273
# 폭(m)                -0.2343      0.444     -0.527      0.599      -1.113       0.644
# 연장(m)                0.1612      0.197      0.819      0.414      -0.228       0.550
# 높이(m)               -0.1499      0.424     -0.354      0.724      -0.988       0.688
# 개방도                  0.5658      0.507      1.115      0.267      -0.438       1.569
# 경사도                  0.0212      0.044      0.478      0.634      -0.067       0.109
# 주변 로드킬 빈도            0.0641      0.656      0.098      0.922      -1.234       1.363
# 산책로까지의 최단 거리(km)    -0.2672      0.094     -2.855      0.005      -0.452      -0.082
# 농가까지의 거리(km)         0.1699      0.383      0.443      0.658      -0.588       0.928
# 도로 최고제한속도(km/h)      0.6713      0.322      2.082      0.039       0.033       1.309
# 주변 동물종 개수            0.2299      0.127      1.805      0.073      -0.022       0.482
# 주변동물 출현빈도           -0.0715      0.031     -2.313      0.022      -0.133      -0.010
# 지형기호(2.3km)          0.1068      0.030      3.563      0.001       0.047       0.166
# 하천거리(km)             0.0896      0.070      1.272      0.206      -0.050       0.229
# 등산로까지 최단거리(km)       0.0721      0.057      1.263      0.209      -0.041       0.185
# 유도울타리_연장_m           0.0629      0.103      0.613      0.541      -0.140       0.266
# 유도울타리_높이_m          -0.2052      0.106     -1.939      0.055      -0.415       0.004
# 교통량                 -0.0559      0.094     -0.596      0.552      -0.241       0.130
# 환경영향평가점수             0.0113      0.049      0.230      0.819      -0.086       0.109
# 건물까지거리(km)           0.2631      0.165      1.599      0.112      -0.062       0.589
# 최우점식물군락             -0.0266      0.016     -1.640      0.103      -0.059       0.005
# ==============================================================================
# Omnibus:                        3.658   Durbin-Watson:                   2.237
# Prob(Omnibus):                  0.161   Jarque-Bera (JB):                4.202
# Skew:                           0.082   Prob(JB):                        0.122
# Kurtosis:                       3.784   Cond. No.                         274.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Optimal number of features : 22
# GridSearch 수행시간 :  6.791738510131836
# 최적 하이퍼 파라미터 : {'C': 0.30000000000000004, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV       0.8  0.775744
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.379
# Model:                            OLS   Adj. R-squared:                  0.277
# Method:                 Least Squares   F-statistic:                     3.718
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):           1.20e-06
# Time:                        09:09:07   Log-Likelihood:                -130.94
# No. Observations:                 157   AIC:                             307.9
# Df Residuals:                     134   BIC:                             378.2
# Df Model:                          22
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.4862      1.053      1.411      0.160      -0.597       3.569
# 차선_수                -0.3415      0.210     -1.630      0.106      -0.756       0.073
# 등산객_이용빈도            -0.4512      0.090     -5.005      0.000      -0.630      -0.273
# 폭(m)                -0.2343      0.444     -0.527      0.599      -1.113       0.644
# 연장(m)                0.1612      0.197      0.819      0.414      -0.228       0.550
# 높이(m)               -0.1499      0.424     -0.354      0.724      -0.988       0.688
# 개방도                  0.5658      0.507      1.115      0.267      -0.438       1.569
# 경사도                  0.0212      0.044      0.478      0.634      -0.067       0.109
# 주변 로드킬 빈도            0.0641      0.656      0.098      0.922      -1.234       1.363
# 산책로까지의 최단 거리(km)    -0.2672      0.094     -2.855      0.005      -0.452      -0.082
# 농가까지의 거리(km)         0.1699      0.383      0.443      0.658      -0.588       0.928
# 도로 최고제한속도(km/h)      0.6713      0.322      2.082      0.039       0.033       1.309
# 주변 동물종 개수            0.2299      0.127      1.805      0.073      -0.022       0.482
# 주변동물 출현빈도           -0.0715      0.031     -2.313      0.022      -0.133      -0.010
# 지형기호(2.3km)          0.1068      0.030      3.563      0.001       0.047       0.166
# 하천거리(km)             0.0896      0.070      1.272      0.206      -0.050       0.229
# 등산로까지 최단거리(km)       0.0721      0.057      1.263      0.209      -0.041       0.185
# 유도울타리_연장_m           0.0629      0.103      0.613      0.541      -0.140       0.266
# 유도울타리_높이_m          -0.2052      0.106     -1.939      0.055      -0.415       0.004
# 교통량                 -0.0559      0.094     -0.596      0.552      -0.241       0.130
# 환경영향평가점수             0.0113      0.049      0.230      0.819      -0.086       0.109
# 건물까지거리(km)           0.2631      0.165      1.599      0.112      -0.062       0.589
# 최우점식물군락             -0.0266      0.016     -1.640      0.103      -0.059       0.005
# ==============================================================================
# Omnibus:                        3.658   Durbin-Watson:                   2.237
# Prob(Omnibus):                  0.161   Jarque-Bera (JB):                4.202
# Skew:                           0.082   Prob(JB):                        0.122
# Kurtosis:                       3.784   Cond. No.                         274.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GridSearch 수행시간 :  6.308560371398926
# 최적 하이퍼 파라미터 : {'C': 0.1, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV      0.44  0.385741
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.424
# Model:                            OLS   Adj. R-squared:                  0.262
# Method:                 Least Squares   F-statistic:                     2.626
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):            0.00120
# Time:                        09:09:13   Log-Likelihood:                -100.44
# No. Observations:                  97   AIC:                             244.9
# Df Residuals:                      75   BIC:                             301.5
# Df Model:                          21
# Covariance Type:            nonrobust
# ====================================================================================
# ...
# No. Observations:                  97   AIC:                             246.4
# Df Residuals:                      77   BIC:                             297.9
# Df Model:                          19
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -0.4231      1.464     -0.289      0.773      -3.338       2.492
# 차선_수                -0.3594      0.251     -1.435      0.155      -0.858       0.139
# 등산객_이용빈도            -0.4850      0.113     -4.295      0.000      -0.710      -0.260
# 폭(m)                -0.2289      0.233     -0.981      0.330      -0.694       0.236
# 연장(m)                0.0252      0.163      0.155      0.877      -0.299       0.349
# 높이(m)                0.4878      0.476      1.026      0.308      -0.459       1.435
# 개방도                  0.3783      0.712      0.531      0.597      -1.040       1.796
# 경사도                  0.0413      0.056      0.739      0.462      -0.070       0.152
# 산책로까지의 최단 거리(km)    -0.1542      0.104     -1.478      0.143      -0.362       0.053
# 농가까지의 거리(km)        -0.0209      0.114     -0.183      0.855      -0.248       0.206
# 도로 최고제한속도(km/h)      0.1333      0.206      0.646      0.520      -0.277       0.544
# 주변 동물종 개수            0.2645      0.199      1.331      0.187      -0.131       0.660
# 주변동물 출현빈도           -0.0828      0.038     -2.178      0.032      -0.158      -0.007
# 하천거리(km)             0.1202      0.088      1.363      0.177      -0.055       0.296
# 등산로까지 최단거리(km)       0.0977      0.091      1.080      0.284      -0.083       0.278
# 유도울타리_연장_m           0.2804      0.193      1.452      0.151      -0.104       0.665
# 유도울타리_높이_m          -0.2587      0.198     -1.307      0.195      -0.653       0.135
# 교통량                  0.0294      0.124      0.236      0.814      -0.218       0.277
# 환경영향평가점수             0.0700      0.066      1.065      0.290      -0.061       0.201
# 건물까지거리(km)           0.1532      0.107      1.433      0.156      -0.060       0.366
# ==============================================================================
# Omnibus:                        2.380   Durbin-Watson:                   1.758
# Prob(Omnibus):                  0.304   Jarque-Bera (JB):                1.690
# Skew:                           0.111   Prob(JB):                        0.429
# Kurtosis:                       2.393   Cond. No.                         153.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GridSearch 수행시간 :  8.269227743148804
# 최적 하이퍼 파라미터 : {'C': 0.4, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV      0.52  0.384717
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.431
# Model:                            OLS   Adj. R-squared:                  0.272
# Method:                 Least Squares   F-statistic:                     2.710
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):           0.000846
# Time:                        09:09:55   Log-Likelihood:                -99.783
# No. Observations:                  97   AIC:                             243.6
# Df Residuals:                      75   BIC:                             300.2
# Df Model:                          21
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.4652      1.766      0.263      0.793      -3.053       3.984
# 차선_수                -0.1399      0.271     -0.517      0.607      -0.679       0.399
# 등산객_이용빈도            -0.5093      0.114     -4.486      0.000      -0.735      -0.283
# 폭(m)                -0.1864      0.369     -0.506      0.614      -0.921       0.548
# 연장(m)                0.0404      0.315      0.129      0.898      -0.586       0.667
# 높이(m)                0.1459      0.494      0.295      0.769      -0.838       1.130
# 개방도                  0.5730      1.244      0.461      0.646      -1.905       3.051
# 경사도                  0.0538      0.055      0.975      0.333      -0.056       0.164
# 주변 로드킬 빈도         3.548e-16   6.17e-15      0.058      0.954   -1.19e-14    1.26e-14
# 산책로까지의 최단 거리(km)    -0.2782      0.104     -2.666      0.009      -0.486      -0.070
# 농가까지의 거리(km)         0.0199      0.112      0.178      0.859      -0.203       0.243
# 도로 최고제한속도(km/h)      0.2479      0.186      1.333      0.186      -0.122       0.618
# 주변 동물종 개수            0.4070      0.210      1.942      0.056      -0.011       0.824
# 주변동물 출현빈도           -0.1129      0.041     -2.762      0.007      -0.194      -0.031
# 지형기호(2.3km)          0.0863      0.037      2.310      0.024       0.012       0.161
# 하천거리(km)             0.0559      0.094      0.597      0.552      -0.131       0.242
# 등산로까지 최단거리(km)       0.1666      0.094      1.781      0.079      -0.020       0.353
# 유도울타리_연장_m          -0.0464      0.165     -0.281      0.779      -0.375       0.282
# 유도울타리_높이_m          -0.1619      0.174     -0.931      0.355      -0.508       0.185
# 교통량                 -0.1144      0.122     -0.935      0.353      -0.358       0.129
# 환경영향평가점수             0.0313      0.066      0.470      0.639      -0.101       0.164
# 건물까지거리(km)           0.0624      0.103      0.606      0.547      -0.143       0.268
# 최우점식물군락             -0.0074      0.022     -0.336      0.738      -0.051       0.036
# ==============================================================================
# Omnibus:                        0.421   Durbin-Watson:                   2.378
# Prob(Omnibus):                  0.810   Jarque-Bera (JB):                0.573
# Skew:                           0.020   Prob(JB):                        0.751
# Kurtosis:                       2.626   Cond. No.                     4.06e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.02e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Optimal number of features : 1
# GridSearch 수행시간 :  1.7994024753570557
# 최적 하이퍼 파라미터 : {'C': 0.0, 'penalty': 'none', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV      0.56  0.406208
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.133
# Model:                            OLS   Adj. R-squared:                  0.124
# Method:                 Least Squares   F-statistic:                     14.63
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):           0.000234
# Time:                        09:09:59   Log-Likelihood:                -120.22
# No. Observations:                  97   AIC:                             244.4
# Df Residuals:                      95   BIC:                             249.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1975      0.115     10.459      0.000       0.970       1.425
# 등산객_이용빈도      -0.4141      0.108     -3.825      0.000      -0.629      -0.199
# ==============================================================================
# Omnibus:                       47.563   Durbin-Watson:                   2.375
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                6.651
# Skew:                           0.025   Prob(JB):                       0.0359
# Kurtosis:                       1.718   Cond. No.                         2.23
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GridSearch 수행시간 :  6.443926095962524
# 최적 하이퍼 파라미터 : {'C': 0.9, 'penalty': 'l2', 'random_state': 3}
#                        Model  Accuracy   F1Score
# 0  Logistic Regression RFECV      0.64  0.476383
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.388
# Model:                            OLS   Adj. R-squared:                  0.216
# Method:                 Least Squares   F-statistic:                     2.262
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):            0.00534
# Time:                        09:10:06   Log-Likelihood:                -103.37
# No. Observations:                  97   AIC:                             250.7
# Df Residuals:                      75   BIC:                             307.4
# Df Model:                          21
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -0.2676      1.496     -0.179      0.859      -3.248       2.713
# 차선_수                -0.1400      0.255     -0.548      0.585      -0.649       0.369
# 등산객_이용빈도            -0.5125      0.126     -4.066      0.000      -0.764      -0.261
# 폭(m)                -0.2287      0.219     -1.045      0.299      -0.665       0.207
# 연장(m)                0.0355      0.133      0.267      0.790      -0.229       0.300
# 높이(m)                0.3617      0.478      0.757      0.452      -0.591       1.314
# 개방도                  0.5096      0.631      0.808      0.422      -0.747       1.767
# 경사도                  0.0607      0.060      1.009      0.316      -0.059       0.181
# 주변 로드킬 빈도        -4.409e-16   1.96e-15     -0.225      0.823   -4.35e-15    3.47e-15
# 산책로까지의 최단 거리(km)    -0.1926      0.113     -1.707      0.092      -0.417       0.032
# 농가까지의 거리(km)         0.0728      0.120      0.605      0.547      -0.167       0.313
# 도로 최고제한속도(km/h)      0.3194      0.191      1.671      0.099      -0.061       0.700
# 주변 동물종 개수            0.2629      0.202      1.298      0.198      -0.141       0.666
# 주변동물 출현빈도           -0.0760      0.038     -1.984      0.051      -0.152       0.000
# 지형기호(2.3km)          0.0386      0.042      0.926      0.357      -0.044       0.122
# 하천거리(km)             0.0639      0.091      0.704      0.484      -0.117       0.245
# 등산로까지 최단거리(km)       0.1061      0.098      1.080      0.283      -0.090       0.302
# 유도울타리_연장_m           0.0506      0.157      0.323      0.748      -0.262       0.363
# 유도울타리_높이_m          -0.3274      0.176     -1.864      0.066      -0.677       0.023
# 교통량                  0.0137      0.130      0.105      0.917      -0.246       0.273
# 환경영향평가점수             0.0172      0.067      0.256      0.799      -0.117       0.151
# 건물까지거리(km)           0.0598      0.118      0.505      0.615      -0.176       0.296
# 최우점식물군락             -0.0052      0.021     -0.244      0.808      -0.048       0.037
# ==============================================================================
# Omnibus:                        2.804   Durbin-Watson:                   2.060
# Prob(Omnibus):                  0.246   Jarque-Bera (JB):                1.742
# Skew:                           0.003   Prob(JB):                        0.418
# Kurtosis:                       2.343   Cond. No.                     9.09e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.99e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Optimal number of features : 12
# GridSearch 수행시간 :  5.931556701660156
# 최적 하이퍼 파라미터 : {'C': 0.0, 'penalty': 'none', 'random_state': 3}
#                        Model  Accuracy  F1Score
# 0  Logistic Regression RFECV       0.6  0.44958
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               생태통로_효율성   R-squared:                       0.330
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     3.455
# Date:                Fri, 19 Aug 2022   Prob (F-statistic):           0.000374
# Time:                        09:10:15   Log-Likelihood:                -107.71
# No. Observations:                  97   AIC:                             241.4
# Df Residuals:                      84   BIC:                             274.9
# Df Model:                          12
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.3599      0.973      0.370      0.712      -1.575       2.294
# 차선_수                -0.1435      0.226     -0.635      0.527      -0.593       0.306
# 등산객_이용빈도            -0.4818      0.113     -4.251      0.000      -0.707      -0.256
# 높이(m)                0.1717      0.384      0.448      0.656      -0.591       0.934
# 개방도                  0.0274      0.374      0.073      0.942      -0.717       0.771
# 경사도                  0.0945      0.056      1.688      0.095      -0.017       0.206
# 산책로까지의 최단 거리(km)    -0.1909      0.090     -2.129      0.036      -0.369      -0.013
# 농가까지의 거리(km)         0.1317      0.090      1.468      0.146      -0.047       0.310
# 도로 최고제한속도(km/h)      0.4129      0.180      2.293      0.024       0.055       0.771
# 주변 동물종 개수           -0.1052      0.087     -1.211      0.229      -0.278       0.068
# 등산로까지 최단거리(km)       0.0666      0.091      0.730      0.467      -0.115       0.248
# 유도울타리_연장_m           0.0333      0.143      0.233      0.816      -0.250       0.317
# 유도울타리_높이_m          -0.3555      0.158     -2.253      0.027      -0.669      -0.042
# ==============================================================================
# Omnibus:                       12.467   Durbin-Watson:                   2.049
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                4.076
# Skew:                          -0.112   Prob(JB):                        0.130
# Kurtosis:                       2.021   Cond. No.                         71.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
