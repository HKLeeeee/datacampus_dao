# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
import pandas as pd
from glob import glob
import numpy as np
from sklearn.metrics import classification_report

# %% [markdown]
# ## Load Data

# %%
files = glob('../../Maindata_predict/도람지/*.csv')
files = [x.replace('\\', '/') for x in files]
df_overpass = pd.read_csv(files[0], encoding='cp949')
df_tunnel = pd.read_csv(files[1], encoding='cp949')
files
# Out:
# ['../../Maindata_predict/도람지/df_tunnel_mean.csv',
#  '../../Maindata_predict/도람지/df_overpass_mean.csv',
#  '../../Maindata_predict/도람지/df_overpass_knn1.csv',
#  '../../Maindata_predict/도람지/df_overpass_knn3.csv',
#  '../../Maindata_predict/도람지/df_overpass_knn5.csv',
#  '../../Maindata_predict/도람지/df_tunnel_knn3.csv',
#  '../../Maindata_predict/도람지/df_tunnel_knn1.csv',
#  '../../Maindata_predict/도람지/df_tunnel_knn5.csv']

# %% [markdown]
# ## Preprocessing

# %%
def preprocess_df(df, onehot_col=None, scaling_col=None, drop_col = None, labeling_col = None, scaling_func=MinMaxScaler) :
    """
    :param df: 사용할 데이터프레임 
    :param onehot_col: default = None, 원핫인코딩할 컬럼 리스트 
    :param scaling_col: default = None, 스케일링할 컬럼 리스트 
    :param drop_col: default = None, 사용하지 않을 컬럼 리스트 
    :param labeling_col: default = None, 라벨링이 필요한 컬럼 리스트 
    :param scaling_func: 스케일링시 사용할 컬럼, MinMaxScaler or StandardScaler
    :return: 전처리 된 데이터 프레임
    """
    if drop_col is not None :
        df = df.drop(drop_col, axis=1)
    if onehot_col is not None:
        df = pd.get_dummies(df, columns= onehot_col)
    if scaling_col is not None :
        for c in scaling_col :
            scaler = scaling_func()
            scaler.fit(df[[c]])
            df[c] = scaler.transform(df[[c]])
    if labeling_col is not None :
        for c in labeling_col :
            encoder = LabelEncoder()
            encoder.fit(df[c])
            df[c] = encoder.transform(df[c])
    return df

# %% [markdown]
# ## Blending

# %%
def blending(df, file_name, target_idx, test_set, voting = False):
    
    clf = setup(data=df, target=target_idx, train_size=0.8)
    print(file_name)
    
    best_model_5 = compare_models(sort = 'Accuracy', n_select = 5)

    # Blending
    blended_model = blend_models(estimator_list = best_model_5, fold = 10)
    
#     plot_model(blended_model, plot='learning')
    final_model = finalize_model(blended_model)
    prediction = predict_model(final_model, data = test_set)
    
    print(file_name)
    print(check_metric(prediction[target_idx], prediction['Label'], metric = 'Accuracy'))

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from pycaret.classification import *
from pycaret.utils import check_metric

onehot_col = ['지형기호(2.3km)', '최우점식물군락']
scaling_col = ['폭(m)', '연장(m)', '산책로까지의 최단 거리(km)', '농가까지의 거리(km)', '도로 최고제한속도(km/h)',
               '하천거리(km)', '주변 동물종 개수', '등산로까지 최단거리(km)', '유도울타리_연장_m', '유도울타리_높이_m', '교통량', 
               '건물까지거리(km)', '주변동물 출현빈도']
drop_col = ['이용확인종_수']
scaling_col_tunnel = scaling_col + ['높이(m)', '개방도']
# Out:
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
for file in files:
    data_set = pd.read_csv(file, encoding='cp949')
    data_set = preprocess_df(df, scaling_col=scaling_col, scaling_func=StandardScaler)
    col_ls = list(data_set.columns)
    target_idx = col_ls.index('일평균이용빈도')

    data_set = data_set.rename(columns={name: str(idx) for idx, name in enumerate(data_set.columns)}, inplace = False)
    train_set, test_set = train_test_split(data_set, test_size=0.2)

    name = file.split('/')[-1].split('.')[0]

    blending(train_set, name, str(target_idx), test_set)
# Out:
# <style type="text/css">
# #T_ddfe4 th {
#   text-align: left;
# }
# #T_ddfe4_row0_col0, #T_ddfe4_row0_col1, #T_ddfe4_row0_col3, #T_ddfe4_row0_col4, #T_ddfe4_row0_col5, #T_ddfe4_row0_col6, #T_ddfe4_row1_col0, #T_ddfe4_row1_col1, #T_ddfe4_row1_col4, #T_ddfe4_row1_col6, #T_ddfe4_row2_col0, #T_ddfe4_row2_col2, #T_ddfe4_row2_col3, #T_ddfe4_row2_col4, #T_ddfe4_row2_col6, #T_ddfe4_row3_col0, #T_ddfe4_row3_col1, #T_ddfe4_row3_col2, #T_ddfe4_row3_col3, #T_ddfe4_row3_col5, #T_ddfe4_row3_col6, #T_ddfe4_row4_col0, #T_ddfe4_row4_col1, #T_ddfe4_row4_col2, #T_ddfe4_row4_col3, #T_ddfe4_row4_col4, #T_ddfe4_row4_col5, #T_ddfe4_row4_col6, #T_ddfe4_row5_col0, #T_ddfe4_row5_col1, #T_ddfe4_row5_col2, #T_ddfe4_row5_col3, #T_ddfe4_row5_col4, #T_ddfe4_row5_col5, #T_ddfe4_row5_col6, #T_ddfe4_row6_col0, #T_ddfe4_row6_col1, #T_ddfe4_row6_col2, #T_ddfe4_row6_col3, #T_ddfe4_row6_col4, #T_ddfe4_row6_col5, #T_ddfe4_row6_col6, #T_ddfe4_row7_col0, #T_ddfe4_row7_col1, #T_ddfe4_row7_col2, #T_ddfe4_row7_col3, #T_ddfe4_row7_col4, #T_ddfe4_row7_col5, #T_ddfe4_row7_col6, #T_ddfe4_row8_col0, #T_ddfe4_row8_col1, #T_ddfe4_row8_col2, #T_ddfe4_row8_col3, #T_ddfe4_row8_col4, #T_ddfe4_row8_col5, #T_ddfe4_row8_col6, #T_ddfe4_row9_col0, #T_ddfe4_row9_col1, #T_ddfe4_row9_col2, #T_ddfe4_row9_col3, #T_ddfe4_row9_col4, #T_ddfe4_row9_col5, #T_ddfe4_row9_col6, #T_ddfe4_row10_col0, #T_ddfe4_row10_col1, #T_ddfe4_row10_col2, #T_ddfe4_row10_col3, #T_ddfe4_row10_col4, #T_ddfe4_row10_col5, #T_ddfe4_row11_col0, #T_ddfe4_row11_col1, #T_ddfe4_row11_col2, #T_ddfe4_row11_col3, #T_ddfe4_row11_col4, #T_ddfe4_row11_col5, #T_ddfe4_row11_col6, #T_ddfe4_row12_col0, #T_ddfe4_row12_col1, #T_ddfe4_row12_col2, #T_ddfe4_row12_col3, #T_ddfe4_row12_col4, #T_ddfe4_row12_col5, #T_ddfe4_row12_col6, #T_ddfe4_row13_col0, #T_ddfe4_row13_col1, #T_ddfe4_row13_col2, #T_ddfe4_row13_col3, #T_ddfe4_row13_col4, #T_ddfe4_row13_col5, #T_ddfe4_row13_col6, #T_ddfe4_row14_col0, #T_ddfe4_row14_col1, #T_ddfe4_row14_col2, #T_ddfe4_row14_col3, #T_ddfe4_row14_col4, #T_ddfe4_row14_col5, #T_ddfe4_row14_col6, #T_ddfe4_row15_col0, #T_ddfe4_row15_col1, #T_ddfe4_row15_col2, #T_ddfe4_row15_col3, #T_ddfe4_row15_col4, #T_ddfe4_row15_col5, #T_ddfe4_row15_col6, #T_ddfe4_row16_col0, #T_ddfe4_row16_col1, #T_ddfe4_row16_col2, #T_ddfe4_row16_col3, #T_ddfe4_row16_col4, #T_ddfe4_row16_col5, #T_ddfe4_row16_col6, #T_ddfe4_row17_col0, #T_ddfe4_row17_col1, #T_ddfe4_row17_col2, #T_ddfe4_row17_col3, #T_ddfe4_row17_col4, #T_ddfe4_row17_col5, #T_ddfe4_row17_col6, #T_ddfe4_row18_col0, #T_ddfe4_row18_col1, #T_ddfe4_row18_col2, #T_ddfe4_row18_col3, #T_ddfe4_row18_col4, #T_ddfe4_row18_col5, #T_ddfe4_row18_col6 {
#   text-align: left;
# }
# #T_ddfe4_row0_col2, #T_ddfe4_row1_col2, #T_ddfe4_row1_col3, #T_ddfe4_row1_col5, #T_ddfe4_row2_col1, #T_ddfe4_row2_col5, #T_ddfe4_row3_col4, #T_ddfe4_row10_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ddfe4_row0_col7, #T_ddfe4_row1_col7, #T_ddfe4_row5_col7, #T_ddfe4_row8_col7, #T_ddfe4_row11_col7, #T_ddfe4_row13_col7, #T_ddfe4_row14_col7, #T_ddfe4_row15_col7, #T_ddfe4_row16_col7, #T_ddfe4_row17_col7, #T_ddfe4_row18_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_ddfe4_row2_col7, #T_ddfe4_row3_col7, #T_ddfe4_row4_col7, #T_ddfe4_row6_col7, #T_ddfe4_row7_col7, #T_ddfe4_row9_col7, #T_ddfe4_row10_col7, #T_ddfe4_row12_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ddfe4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ddfe4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ddfe4_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ddfe4_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ddfe4_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ddfe4_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ddfe4_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ddfe4_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ddfe4_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ddfe4_level0_row0" class="row_heading level0 row0" >omp</th>
#       <td id="T_ddfe4_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_ddfe4_row0_col1" class="data row0 col1" >0.0696</td>
#       <td id="T_ddfe4_row0_col2" class="data row0 col2" >0.0124</td>
#       <td id="T_ddfe4_row0_col3" class="data row0 col3" >0.1051</td>
#       <td id="T_ddfe4_row0_col4" class="data row0 col4" >0.8834</td>
#       <td id="T_ddfe4_row0_col5" class="data row0 col5" >0.0686</td>
#       <td id="T_ddfe4_row0_col6" class="data row0 col6" >0.1814</td>
#       <td id="T_ddfe4_row0_col7" class="data row0 col7" >0.0020</td>
#     </tr>
#     <tr>
#       <th id="T_ddfe4_level0_row1" class="row_heading level0 row1" >br</th>
#       <td id="T_ddfe4_row1_col0" class="data row1 col0" >Bayesian Ridge</td>
#       <td id="T_ddfe4_row1_col1" class="data row1 col1" >0.0499</td>
#       <td id="T_ddfe4_row1_col2" class="data row1 col2" >0.0124</td>
#       <td id="T_ddfe4_row1_col3" class="data row1 col3" >0.0958</td>
#       <td id="T_ddfe4_row1_col4" class="data row1 col4" >0.8717</td>
#       <td id="T_ddfe4_row1_col5" class="data row1 col5" >0.0542</td>
#       <td id="T_ddfe4_row1_col6" class="data row1 col6" >0.1537</td>
#       <td id="T_ddfe4_row1_col7" class="data row1 col7" >0.0020</td>
#     </tr>
#     <tr>
#       <th id="T_ddfe4_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_ddfe4_row2_col0" class="data row2 col0" >Linear Regression</td>
#       <td id="T_ddfe4_row2_col1" class="data row2 col1" >0.0495</td>
#       <td id="T_ddfe4_row2_col2" class="data row2 col2" >0.0127</td>
#       <td id="T_ddfe4_row2_col3" class="data row2 col3" >0.0967</td>
#       <td id="T_ddfe4_row2_col4" class="data row2 col4" >0.8683</td>
#       <td id="T_ddfe4_row2_col5" class="data row2 col5" >0.0542</td>
#       <td id="T_ddfe4_row2_col6" class="data row2 col6" >0.1544</td>
#       <td id="T_ddfe4_row2_col7" class="data row2 col7" >0.1400</td>
#     </tr>
#     <tr>
#       <th id="T_ddfe4_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_ddfe4_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_ddfe4_row3_col1" class="data row3 col1" >0.0545</td>
#       <td id="T_ddfe4_row3_col2" class="data row3 col2" >0.0148</td>
#       <td id="T_ddfe4_row3_col3" class="data row3 col3" >0.1160</td>
#       <td id="T_ddfe4_row3_col4" class="data row3 col4" >0.8943</td>
#       <td id="T_ddfe4_row3_col5" class="data row3 col5" >0.0718</td>
#       <td id="T_ddfe4_row3_col6" class="data row3 col6" >0.1591</td>
#       <td id="T_ddfe4_row3_col7" class="data row3 col7" >0.0080</td>
#     </tr>
#     <tr>
#       <th id="T_ddfe4_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_ddfe4_row4_col0" class="data row4 col0" >Extra Trees Regressor</td>
#       <td id="T_ddfe4_row4_col1" class="data row4 col1" >0.0573</td>
#       <td id="T_ddfe4_row4_col2" class="data row4 col2" >0.0178</td>
#       <td id="T_ddfe4_row4_col3" class="data row4 col3" >0.1270</td>
#       <td id="T_ddfe4_row4_col4" class="data row4 col4" >0.8603</td>
#       <td id="T_ddfe4_row4_col5" class="data row4 col5" >0.0745</td>
#       <td id="T_ddfe4_row4_col6" class="data row4 col6" >0.1681</td>
#       <td id="T_ddfe4_row4_col7" class="data row4 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_ddfe4_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_ddfe4_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_ddfe4_row5_col1" class="data row5 col1" >0.0749</td>
#       <td id="T_ddfe4_row5_col2" class="data row5 col2" >0.0193</td>
#       <td id="T_ddfe4_row5_col3" class="data row5 col3" >0.1297</td>
#       <td id="T_ddfe4_row5_col4" class="data row5 col4" >0.8546</td>
#       <td id="T_ddfe4_row5_col5" class="data row5 col5" >0.0632</td>
#       <td id="T_ddfe4_row5_col6" class="dat
# df_tunnel_mean
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            19:33:04
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Text(value="Following data types have been inferred automatically, if they are correct press enter to continue…
#       Data Type
# 0       Numeric
# 1       Numeric
# 2       Numeric
# 3       Numeric
# 4       Numeric
# 5       Numeric
# 6       Numeric
# 7   Categorical
# 8       Numeric
# 9       Numeric
# 10      Numeric
# 11      Numeric
# 12      Numeric
# 13      Numeric
# 14      Numeric
# 15      Numeric
# 17  Categorical
# 18  Categorical
# 19  Categorical
# 20  Categorical
# 21  Categorical
# 22  Categorical
# 23  Categorical
# 24  Categorical
# 25  Categorical
# 26  Categorical
# 27  Categorical
# 28  Categorical
# 29  Categorical
# 30  Categorical
# 31  Categorical
# 32  Categorical
# 33  Categorical
# 34  Categorical
# 35  Categorical
# 36  Categorical
# 37  Categorical
# 38  Categorical
# 39  Categorical
# 16        Label
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1254: FutureWarning: the classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1262: FutureWarning: the n_classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1254: FutureWarning: the classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1262: FutureWarning: the n_classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1254: FutureWarning: the classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1262: FutureWarning: the n_classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1254: FutureWarning: the classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1262: FutureWarning: the n_classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1254: FutureWarning: the classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1262: FutureWarning: the n_classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1254: FutureWarning: the classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1262: FutureWarning: the n_classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1254: FutureWarning: the classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1262: FutureWarning: the n_classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_least_angle.py:571: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 50 iterations, i.e. alpha=5.096e-02, with an active set of 40 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   warnings.warn('Regressors in active set degenerate. '
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1254: FutureWarning: the classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1262: FutureWarning: the n_classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1254: FutureWarning: the classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1262: FutureWarning: the n_classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1254: FutureWarning: the classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1262: FutureWarning: the n_classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
