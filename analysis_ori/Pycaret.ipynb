# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from pycaret.regression import *
# Out:
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ## Load Files

# %%
file_path = "/Users/hyunsubong/Library/CloudStorage/OneDrive-명지대학교/Univ/2022-1/테청캠/Code/MainData_전처리_결과_데이터_v2"
folder_list = [f for f in os.listdir(file_path) if not f.startswith('.')]

data_list = []
for i in folder_list:
    data = pd.read_csv(file_path + '/' + i, encoding="cp949")
    data_list.append(data)

for idx, file in enumerate(folder_list):
    file = file.rstrip(".csv")
    folder_list[idx] = file
    
print("총 {}개의 파일을 불러왔습니다.\n".format(len(folder_list)))
# Out:
# 총 24개의 파일을 불러왔습니다.

# %% [markdown]
# ## 전처리

# %%
def preprocess_df(df, onehot_col=None, scaling_col=None, drop_col = None, labeling_col = None, scaling_func=MinMaxScaler) :
    """
    :param df: 사용할 데이터프레임 
    :param onehot_col: default = None, 원핫인코딩할 컬럼 리스트 
    :param scaling_col: default = None, 스케일링할 컬럼 리스트 
    :param drop_col: default = None, 사용하지 않을 컬럼 리스트 
    :param labeling_col: default = None, 라벨링이 필요한 컬럼 리스트 
    :param scaling_func: 스케일링시 사용할 컬럼, MinMaxScaler or StandardScaler
    :return: 전처리 된 데이터 프레임
    """
    if drop_col is not None :
        df = df.drop(drop_col, axis=1)
    if onehot_col is not None:
        df = pd.get_dummies(df, columns= onehot_col)
    if scaling_col is not None :
        for c in scaling_col :
            scaler = scaling_func()
            scaler.fit(df[[c]])
            df[c] = scaler.transform(df[[c]])
    if labeling_col is not None :
        for c in labeling_col :
            encoder = LabelEncoder()
            encoder.fit(df[c])
            df[c] = encoder.transform(df[c])
    return df

# %%
onehot_col = ['지형기호(2.3km)', '최우점식물군락']
scaling_col = ['폭(m)', '연장(m)', '주변 로드킬 빈도', '산책로까지의 최단 거리(km)', '농가까지의 거리(km)', '도로 최고제한속도(km/h)',
               '하천거리(km)', '주변 동물종 개수', '등산로까지 최단거리(km)', '유도울타리_연장_m', '유도울타리_높이_m', '교통량', 
               '건물까지거리(km)', '주변동물 출현빈도']
drop_col = ['번호', '위도', '경도', '생태통로_유형', '이용확인종_수', '유도울타리_위도_2.3km', '유도울타리_경도_2.3km', '식물군락명']
scaling_col_tunnel = scaling_col + ['높이(m)', '개방도']

# %% [markdown]
# ## 모델 비교 (특정)

# %%
while(True):
    print('데이터셋 목록 :\n', '\n'.join([str(elem) for elem in folder_list]))
    target_name = input("찾고자하는 데이터의 이름을 입력하십시오. 종료는 quit를 입력하십시오.")
    if target_name == "quit":
        break
    target_idx = folder_list.index(target_name)

    train_set = preprocess_df(data_list[13], drop_col=drop_col, labeling_col=onehot_col, scaling_col=scaling_col, scaling_func=StandardScaler)
    train_set = train_set.rename(columns={name: str(idx) for idx, name in enumerate(train_set.columns)}, inplace = False)
    setup_rgs = setup(data = train_set, target = '2',session_id = 10)
    best_model_top5 = compare_models(sort='MSE', n_select=5)
    print("분석 데이터 => " + folder_list[target_idx] + "\n")
# Out:
# <style type="text/css">
# #T_cece3 th {
#   text-align: left;
# }
# #T_cece3_row0_col0, #T_cece3_row0_col1, #T_cece3_row0_col5, #T_cece3_row0_col6, #T_cece3_row1_col0, #T_cece3_row1_col1, #T_cece3_row1_col2, #T_cece3_row1_col3, #T_cece3_row1_col4, #T_cece3_row1_col5, #T_cece3_row2_col0, #T_cece3_row2_col1, #T_cece3_row2_col2, #T_cece3_row2_col3, #T_cece3_row2_col4, #T_cece3_row2_col5, #T_cece3_row3_col0, #T_cece3_row3_col1, #T_cece3_row3_col2, #T_cece3_row3_col3, #T_cece3_row3_col4, #T_cece3_row3_col5, #T_cece3_row4_col0, #T_cece3_row4_col1, #T_cece3_row4_col2, #T_cece3_row4_col3, #T_cece3_row4_col4, #T_cece3_row4_col5, #T_cece3_row5_col0, #T_cece3_row5_col2, #T_cece3_row5_col3, #T_cece3_row5_col4, #T_cece3_row5_col5, #T_cece3_row5_col6, #T_cece3_row6_col0, #T_cece3_row6_col1, #T_cece3_row6_col2, #T_cece3_row6_col3, #T_cece3_row6_col4, #T_cece3_row6_col5, #T_cece3_row6_col6, #T_cece3_row7_col0, #T_cece3_row7_col1, #T_cece3_row7_col2, #T_cece3_row7_col3, #T_cece3_row7_col4, #T_cece3_row7_col5, #T_cece3_row7_col6, #T_cece3_row8_col0, #T_cece3_row8_col1, #T_cece3_row8_col2, #T_cece3_row8_col3, #T_cece3_row8_col4, #T_cece3_row8_col5, #T_cece3_row8_col6, #T_cece3_row9_col0, #T_cece3_row9_col1, #T_cece3_row9_col2, #T_cece3_row9_col3, #T_cece3_row9_col4, #T_cece3_row9_col5, #T_cece3_row9_col6, #T_cece3_row10_col0, #T_cece3_row10_col1, #T_cece3_row10_col2, #T_cece3_row10_col3, #T_cece3_row10_col4, #T_cece3_row10_col6, #T_cece3_row11_col0, #T_cece3_row11_col1, #T_cece3_row11_col2, #T_cece3_row11_col3, #T_cece3_row11_col4, #T_cece3_row11_col5, #T_cece3_row11_col6, #T_cece3_row12_col0, #T_cece3_row12_col1, #T_cece3_row12_col2, #T_cece3_row12_col3, #T_cece3_row12_col4, #T_cece3_row12_col5, #T_cece3_row12_col6, #T_cece3_row13_col0, #T_cece3_row13_col1, #T_cece3_row13_col2, #T_cece3_row13_col3, #T_cece3_row13_col4, #T_cece3_row13_col5, #T_cece3_row13_col6, #T_cece3_row14_col0, #T_cece3_row14_col1, #T_cece3_row14_col2, #T_cece3_row14_col3, #T_cece3_row14_col4, #T_cece3_row14_col5, #T_cece3_row14_col6, #T_cece3_row15_col0, #T_cece3_row15_col1, #T_cece3_row15_col2, #T_cece3_row15_col3, #T_cece3_row15_col4, #T_cece3_row15_col5, #T_cece3_row15_col6, #T_cece3_row16_col0, #T_cece3_row16_col1, #T_cece3_row16_col2, #T_cece3_row16_col3, #T_cece3_row16_col4, #T_cece3_row16_col5, #T_cece3_row16_col6, #T_cece3_row17_col0, #T_cece3_row17_col1, #T_cece3_row17_col2, #T_cece3_row17_col3, #T_cece3_row17_col4, #T_cece3_row17_col5, #T_cece3_row17_col6, #T_cece3_row18_col0, #T_cece3_row18_col1, #T_cece3_row18_col2, #T_cece3_row18_col3, #T_cece3_row18_col4, #T_cece3_row18_col5, #T_cece3_row18_col6 {
#   text-align: left;
# }
# #T_cece3_row0_col2, #T_cece3_row0_col3, #T_cece3_row0_col4, #T_cece3_row1_col6, #T_cece3_row2_col6, #T_cece3_row3_col6, #T_cece3_row4_col6, #T_cece3_row5_col1, #T_cece3_row10_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_cece3_row0_col7, #T_cece3_row1_col7, #T_cece3_row2_col7, #T_cece3_row3_col7, #T_cece3_row4_col7, #T_cece3_row6_col7, #T_cece3_row8_col7, #T_cece3_row12_col7, #T_cece3_row15_col7, #T_cece3_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_cece3_row5_col7, #T_cece3_row7_col7, #T_cece3_row9_col7, #T_cece3_row10_col7, #T_cece3_row11_col7, #T_cece3_row13_col7, #T_cece3_row14_col7, #T_cece3_row17_col7, #T_cece3_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_cece3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cece3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cece3_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_cece3_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_cece3_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_cece3_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_cece3_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_cece3_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_cece3_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cece3_level0_row0" class="row_heading level0 row0" >br</th>
#       <td id="T_cece3_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_cece3_row0_col1" class="data row0 col1" >0.6972</td>
#       <td id="T_cece3_row0_col2" class="data row0 col2" >0.8746</td>
#       <td id="T_cece3_row0_col3" class="data row0 col3" >0.9182</td>
#       <td id="T_cece3_row0_col4" class="data row0 col4" >-0.0037</td>
#       <td id="T_cece3_row0_col5" class="data row0 col5" >0.4677</td>
#       <td id="T_cece3_row0_col6" class="data row0 col6" >1.4264</td>
#       <td id="T_cece3_row0_col7" class="data row0 col7" >0.0020</td>
#     </tr>
#     <tr>
#       <th id="T_cece3_level0_row1" class="row_heading level0 row1" >llar</th>
#       <td id="T_cece3_row1_col0" class="data row1 col0" >Lasso Least Angle Regression</td>
#       <td id="T_cece3_row1_col1" class="data row1 col1" >0.7058</td>
#       <td id="T_cece3_row1_col2" class="data row1 col2" >0.9124</td>
#       <td id="T_cece3_row1_col3" class="data row1 col3" >0.9391</td>
#       <td id="T_cece3_row1_col4" class="data row1 col4" >-0.0491</td>
#       <td id="T_cece3_row1_col5" class="data row1 col5" >0.5497</td>
#       <td id="T_cece3_row1_col6" class="data row1 col6" >1.0260</td>
#       <td id="T_cece3_row1_col7" class="data row1 col7" >0.0020</td>
#     </tr>
#     <tr>
#       <th id="T_cece3_level0_row2" class="row_heading level0 row2" >dummy</th>
#       <td id="T_cece3_row2_col0" class="data row2 col0" >Dummy Regressor</td>
#       <td id="T_cece3_row2_col1" class="data row2 col1" >0.7058</td>
#       <td id="T_cece3_row2_col2" class="data row2 col2" >0.9124</td>
#       <td id="T_cece3_row2_col3" class="data row2 col3" >0.9391</td>
#       <td id="T_cece3_row2_col4" class="data row2 col4" >-0.0491</td>
#       <td id="T_cece3_row2_col5" class="data row2 col5" >0.5497</td>
#       <td id="T_cece3_row2_col6" class="data row2 col6" >1.0260</td>
#       <td id="T_cece3_row2_col7" class="data row2 col7" >0.0020</td>
#     </tr>
#     <tr>
#       <th id="T_cece3_level0_row3" class="row_heading level0 row3" >lasso</th>
#       <td id="T_cece3_row3_col0" class="data row3 col0" >Lasso Regression</td>
#       <td id="T_cece3_row3_col1" class="data row3 col1" >0.7058</td>
#       <td id="T_cece3_row3_col2" class="data row3 col2" >0.9124</td>
#       <td id="T_cece3_row3_col3" class="data row3 col3" >0.9391</td>
#       <td id="T_cece3_row3_col4" class="data row3 col4" >-0.0491</td>
#       <td id="T_cece3_row3_col5" class="data row3 col5" >0.5497</td>
#       <td id="T_cece3_row3_col6" class="data row3 col6" >1.0260</td>
#       <td id="T_cece3_row3_col7" class="data row3 col7" >0.0020</td>
#     </tr>
#     <tr>
#       <th id="T_cece3_level0_row4" class="row_heading level0 row4" >en</th>
#       <td id="T_cece3_row4_col0" class="data row4 col0" >Elastic Net</td>
#       <td id="T_cece3_row4_col1" class="data row4 col1" >0.7058</td>
#       <td id="T_cece3_row4_col2" class="data row4 col2" >0.9124</td>
#       <td id="T_cece3_row4_col3" class="data row4 col3" >0.9391</td>
#       <td id="T_cece3_row4_col4" class="data row4 col4" >-0.0491</td>
#       <td id="T_cece3_row4_col5" class="data row4 col5" >0.5497</td>
#       <td id="T_cece3_row4_col6" class="data row4 col6" >1.0260</td>
#       <td id="T_cece3_row4_col7" class="data row4 col7" >0.0020</td>
#     </tr>
#     <tr>
#       <th id="T_cece3_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_cece3_row5_col0" class="data row5 col0" >Random Forest Regressor</td>
#       <td id="T_cece3_row5_col1" class="data row5 col1" >0.6953</td>
#       <td id="T_cece3_row5_col2" class="data row5 col2" >0.9161</td>
#       <td id="T_cece3_row5_col3" class="data row5 col3" >0.9414</td>
#       <td id="T_cece3_row5_col4" class="data row5 col4" >-0.1022</td>
#       <td id="T_cece3_row5_col5" class="data row5 col5" >0.3942</td>
#       <td id="T_cece3_row5_col6" class="data row5
# 분석 데이터 => tunnel_knn3_median
#
# 데이터셋 목록 :
#  overpass_knn2_median
# overpass_mean_drop
# overpass_knn1_drop
# tunnel_knn1_drop
# tunnel_mean_drop
# tunnel_knn2_median
# tunnel_knn5_median
# overpass_knn5_median
# overpass_mean_median
# tunnel_knn3_median
# tunnel_knn2_drop
# tunnel_knn3_drop
# tunnel_mean_median
# overpass_knn3_median
# overpass_knn2_drop
# overpass_knn3_drop
# overpass_knn5_drop
# overpass_knn4_drop
# overpass_knn4_median
# tunnel_knn1_median
# tunnel_knn4_median
# overpass_knn1_median
# tunnel_knn5_drop
# tunnel_knn4_drop
# 찾고자하는 데이터의 이름을 입력하십시오. 종료는 quit를 입력하십시오.quit

# %% [markdown]
# ## 모델 비교 (전체)

# %%
"""
compare_models()
fold: cross_validation의 fold를 지정 (default = 10)
sort: 정렬기준 지표 설정
n_select: 상위 n개의 모델 결과만 출력
"""

for idx, data in enumerate(data_list, start=0):
    train_set = preprocess_df(data, drop_col=drop_col, labeling_col=onehot_col, scaling_col=scaling_col, scaling_func=StandardScaler)
    train_set = train_set.rename(columns={name: str(idx) for idx, name in enumerate(train_set.columns)}, inplace = False)
    setup_rgs = setup(data = train_set, target = '2',session_id = 10)
    best_model_top5 = compare_models(sort='MSE', n_select=5)
    print("분석 데이터 => " + folder_list[idx] + "\n")
# Out:
# <style type="text/css">
# #T_9f98a th {
#   text-align: left;
# }
# #T_9f98a_row0_col0, #T_9f98a_row0_col1, #T_9f98a_row0_col5, #T_9f98a_row0_col6, #T_9f98a_row1_col0, #T_9f98a_row1_col1, #T_9f98a_row1_col2, #T_9f98a_row1_col3, #T_9f98a_row1_col4, #T_9f98a_row1_col5, #T_9f98a_row2_col0, #T_9f98a_row2_col1, #T_9f98a_row2_col2, #T_9f98a_row2_col3, #T_9f98a_row2_col4, #T_9f98a_row2_col5, #T_9f98a_row3_col0, #T_9f98a_row3_col1, #T_9f98a_row3_col2, #T_9f98a_row3_col3, #T_9f98a_row3_col4, #T_9f98a_row3_col5, #T_9f98a_row4_col0, #T_9f98a_row4_col1, #T_9f98a_row4_col2, #T_9f98a_row4_col3, #T_9f98a_row4_col4, #T_9f98a_row4_col5, #T_9f98a_row5_col0, #T_9f98a_row5_col2, #T_9f98a_row5_col3, #T_9f98a_row5_col4, #T_9f98a_row5_col5, #T_9f98a_row5_col
row5_col0" class="data row5 col0" >Random Forest Regressor</td>
#       <td id="T_9f98a_row5_col1" class="data row5 col1" >0.6953</td>
#       <td id="T_9f98a_row5_col2" class="data row5 col2" >0.9161</td>
#       <td id="T_9f98a_row5_col3" class="data row5 col3" >0.9414</td>
#       <td id="T_9f98a_row5_col4" class="data row5 col4" >-0.1022</td>
#       <td id="T_9f98a_row5_col5" class="data row5 col5" >0.3942</td>
#       <td id="T_9f98a_row5_col6" class="data row5
# 분석 데이터 => tunnel_knn3_median
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                15:17:57
# Status     . . . . . . . . . . . . . . . . . .  Compiling Final Models
# Estimator  . . . . . . . . . . . . . . . . . .             Elastic Net
# Text(value="Following data types have been inferred automatically, if they are correct press enter to continue…
#       Data Type
# 0       Numeric
# 1   Categorical
# 3       Numeric
# 4   Categorical
# 5       Numeric
# 6       Numeric
# 7       Numeric
# 8       Numeric
# 9       Numeric
# 10      Numeric
# 11  Categorical
# 12      Numeric
# 13      Numeric
# 14      Numeric
# 15      Numeric
# 16      Numeric
# 17  Categorical
# 18      Numeric
# 19  Categorical
# 20  Categorical
# 2         Label
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1254: FutureWarning: the classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1262: FutureWarning: the n_classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1254: FutureWarning: the classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1262: FutureWarning: the n_classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1254: FutureWarning: the classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1262: FutureWarning: the n_classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1254: FutureWarning: the classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1262: FutureWarning: the n_classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1254: FutureWarning: the classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1262: FutureWarning: the n_classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1254: FutureWarning: the classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1262: FutureWarning: the n_classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1254: FutureWarning: the classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1262: FutureWarning: the n_classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1254: FutureWarning: the classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1262: FutureWarning: the n_classes_ attribute is to be deprecated from v
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 8>()
#       9 train_set = preprocess_df(data, drop_col=drop_col, labeling_col=onehot_col, scaling_col=scaling_col, scaling_func=StandardScaler)
#      10 train_set = train_set.rename(columns={name: str(idx) for idx, name in enumerate(train_set.columns)}, inplace = False)
# ---> 11 setup_rgs = setup(data = train_set, target = '2',session_id = 10)
#      12 best_model_top5 = compare_models(sort='MSE', n_select=5)
#      13 print("분석 데이터 => " + folder_list[idx] + "\n")
#
# File ~/miniforge3/envs/pycaret/lib/python3.8/site-packages/pycaret/regression.py:593, in setup(data, target, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs)
#     590 if log_plots == True:
#     591     log_plots = ["residuals", "error", "feature"]
# --> 593 return pycaret.internal.tabular.setup(
#     594     ml_usecase="regression",
#     595     available_plots=available_plots,
#     596     data=data,
#     597     target=target,
#     598     train_size=train_size,
#     599     test_data=test_data,
#     600     preprocess=preprocess,
#     601     imputation_type=imputation_type,
#     602     iterative_imputation_iters=iterative_imputation_iters,
#     603     categorical_features=categorical_features,
#     604     categorical_imputation=categorical_imputation,
#     605     categorical_iterative_imputer=categorical_iterative_imputer,
#     606     ordinal_features=ordinal_features,
#     607     high_cardinality_features=high_cardinality_features,
#     608     high_cardinality_method=high_cardinality_method,
#     609     numeric_features=numeric_features,
#     610     numeric_imputation=numeric_imputation,
#     611     numeric_iterative_imputer=numeric_iterative_imputer,
#     612     date_features=date_features,
#     613     ignore_features=ignore_features,
#     614     normalize=normalize,
#     615     normalize_method=normalize_method,
#     616     transformation=transformation,
#     617     transformation_method=transformation_method,
#     618     handle_unknown_categorical=handle_unknown_categorical,
#     619     unknown_categorical_method=unknown_categorical_method,
#     620     pca=pca,
#     621     pca_method=pca_method,
#     622     pca_components=pca_components,
#     623     ignore_low_variance=ignore_low_variance,
#     624     combine_rare_levels=combine_rare_levels,
#     625     rare_level_threshold=rare_level_threshold,
#     626     bin_numeric_features=bin_numeric_features,
#     627     remove_outliers=remove_outliers,
#     628     outliers_threshold=outliers_threshold,
#     629     remove_multicollinearity=remove_multicollinearity,
#     630     multicollinearity_threshold=multicollinearity_threshold,
#     631     remove_perfect_collinearity=remove_perfect_collinearity,
#     632     create_clusters=create_clusters,
#     633     cluster_iter=cluster_iter,
#     634     polynomial_features=polynomial_features,
#     635     polynomial_degree=polynomial_degree,
#     636     trigonometry_features=trigonometry_features,
#     637     polynomial_threshold=polynomial_threshold,
#     638     group_features=group_features,
#     639     group_names=group_names,
#     640     feature_selection=feature_selection,
#     641     feature_selection_threshold=feature_selection_threshold,
#     642     feature_selection_method=feature_selection_method,
#     643     feature_interaction=feature_interaction,
#     644     feature_ratio=feature_ratio,
#     645     interaction_threshold=interaction_threshold,
#     646     transform_target=transform_target,
#     647     transform_target_method=transform_target_method,
#     648     data_split_shuffle=data_split_shuffle,
#     649     data_split_stratify=data_split_stratify,
#     650     fold_strategy=fold_strategy,
#     651     fold=fold,
#     652     fold_shuffle=fold_shuffle,
#     653     fold_groups=fold_groups,
#     654     n_jobs=n_jobs,
#     655     use_gpu=use_gpu,
#     656     custom_pipeline=custom_pipeline,
#     657     html=html,
#     658     session_id=session_id,
#     659     log_experiment=log_experiment,
#     660     experiment_name=experiment_name,
#     661     experiment_custom_tags=experiment_custom_tags,
#     662     log_plots=log_plots,
#     663     log_profile=log_profile,
#     664     log_data=log_data,
#     665     silent=silent,
#     666     verbose=verbose,
#     667     profile=profile,
#     668     profile_kwargs=profile_kwargs,
#     669 )
#
# File ~/miniforge3/envs/pycaret/lib/python3.8/site-packages/pycaret/internal/tabular.py:1408, in setup(data, target, ml_usecase, available_plots, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs, display)
#    1405     train_data = pd.concat([X_train, y_train], axis=1)
#    1406     test_data = pd.concat([X_test, y_test], axis=1)
# -> 1408 train_data = prep_pipe.fit_transform(train_data)
#    1409 # workaround to also transform target
#    1410 dtypes.final_training_columns.append(target)
#
# File ~/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/pipeline.py:367, in Pipeline.fit_transform(self, X, y, **fit_params)
#     340 """Fit the model and transform with the final estimator
#     341
#     342 Fits all the transforms one after the other and transforms the
#    (...)
#     364     Transformed samples
#     365 """
#     366 fit_params_steps = self._check_fit_params(**fit_params)
# --> 367 Xt = self._fit(X, y, **fit_params_steps)
#     369 last_step = self._final_estimator
#     370 with _print_elapsed_time('Pipeline',
#     371                          self._log_message(len(self.steps) - 1)):
#
# File ~/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/pipeline.py:292, in Pipeline._fit(self, X, y, **fit_params_steps)
#     290     cloned_transformer = clone(transformer)
#     291 # Fit or load from cache the current transformer
# --> 292 X, fitted_transformer = fit_transform_one_cached(
#     293     cloned_transformer, X, y, None,
#     294     message_clsname='Pipeline',
#     295     message=self._log_message(step_idx),
#     296     **fit_params_steps[name])
#     297 # Replace the transformer of the step with the fitted
#     298 # transformer. This is necessary when loading the transformer
#     299 # from the cache.
#     300 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~/miniforge3/envs/pycaret/lib/python3.8/site-packages/joblib/memory.py:349, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     348 def __call__(self, *args, **kwargs):
# --> 349     return self.func(*args, **kwargs)
#
# File ~/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/pipeline.py:740, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     738 with _print_elapsed_time(message_clsname, message):
#     739     if hasattr(transformer, 'fit_transform'):
# --> 740         res = transformer.fit_transform(X, y, **fit_params)
#     741     else:
#     742         res = transformer.fit(X, y, **fit_params).transform(X)
#
# File ~/miniforge3/envs/pycaret/lib/python3.8/site-packages/pycaret/internal/preprocess.py:421, in DataTypes_Auto_infer.fit_transform(self, dataset, y)
#     418 data = dataset
#     420 # since this is for training , we dont nees any transformation since it has already been transformed in fit
# --> 421 data = self.fit(data)
#     423 # additionally we just need to treat the target variable
#     424 # for ml use ase
#     425 if (self.ml_usecase == "classification") & (
#     426     data[self.target].dtype == "object"
#     427 ):
#
# File ~/miniforge3/envs/pycaret/lib/python3.8/site-packages/pycaret/internal/preprocess.py:323, in DataTypes_Auto_infer.fit(self, dataset, y)
#     320 dt_print_out.drop(index="dummy_target", errors="ignore", inplace=True)
#     322 display(dt_print_out[["Data Type"]])
# --> 323 self.response = input()
#     325 if self.response in [
#     326     "quit",
#     327     "Quit",
#    (...)
#     335     "Exit",
#     336 ]:
#     337     sys.exit(
#     338         "Read the documentation of setup to learn how to overwrite data types over the inferred types. setup function must run again before you continue modeling."
#     339     )
#
# File ~/miniforge3/envs/pycaret/lib/python3.8/site-packages/ipykernel/kernelbase.py:1177, in Kernel.raw_input(self, prompt)
#    1173 if not self._allow_stdin:
#    1174     raise StdinNotImplementedError(
#    1175         "raw_input was called, but this frontend does not support input requests."
#    1176     )
# -> 1177 return self._input_request(
#    1178     str(prompt),
#    1179     self._parent_ident["shell"],
#    1180     self.get_parent("shell"),
#    1181     password=False,
#    1182 )
#
# File ~/miniforge3/envs/pycaret/lib/python3.8/site-packages/ipykernel/kernelbase.py:1219, in Kernel._input_request(self, prompt, ident, parent, password)
#    1216             break
#    1217 except KeyboardInterrupt:
#    1218     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219     raise KeyboardInterrupt("Interrupted by user") from None
#    1220 except Exception:
#    1221     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
# ersion 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1254: FutureWarning: the classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/tree/_classes.py:1262: FutureWarning: the n_classes_ attribute is to be deprecated from version 0.22 and will be removed in 0.24.
#   warnings.warn(msg, FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/hyunsubong/miniforge3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:

# %% [markdown]
# ## Model

# %%
from sklearn.model_selection import train_test_split

data_set = preprocess_df(data_list[11], drop_col=drop_col, labeling_col=onehot_col, scaling_col=scaling_col, scaling_func=StandardScaler)
# data_set.rename(columns={name: str(idx) for idx, name in enumerate(data_set.columns)}, inplace = True)
train_set, test_set = train_test_split(data_set, test_size=0.2)

# setup_rgs = setup(data = train_set, target = '2', session_id = 10)
setup_rgs = setup(data = train_set, target = '생태통로_효율성', session_id = 10)

lasso = create_model('lasso')
lasso_least_angle = create_model('llar')
dummy = create_model('dummy')
elastic = create_model('en')
bayesian = create_model('br')
# Out:
# <style type="text/css">
# #T_83cb9_row10_col0, #T_83cb9_row10_col1, #T_83cb9_row10_col2, #T_83cb9_row10_col3, #T_83cb9_row10_col4, #T_83cb9_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_83cb9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83cb9_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_83cb9_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_83cb9_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_83cb9_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_83cb9_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_83cb9_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83cb9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_83cb9_row0_col0" class="data row0 col0" >0.8714</td>
#       <td id="T_83cb9_row0_col1" class="data row0 col1" >0.9211</td>
#       <td id="T_83cb9_row0_col2" class="data row0 col2" >0.9597</td>
#       <td id="T_83cb9_row0_col3" class="data row0 col3" >-0.0746</td>
#       <td id="T_83cb9_row0_col4" class="data row0 col4" >0.5044</td>
#       <td id="T_83cb9_row0_col5" class="data row0 col5" >0.5247</td>
#     </tr>
#     <tr>
#       <th id="T_83cb9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_83cb9_row1_col0" class="data row1 col0" >0.4558</td>
#       <td id="T_83cb9_row1_col1" class="data row1 col1" >0.4114</td>
#       <td id="T_83cb9_row1_col2" class="data row1 col2" >0.6414</td>
#       <td id="T_83cb9_row1_col3" class="data row1 col3" >-0.0080</td>
#       <td id="T_83cb9_row1_col4" class="data row1 col4" >0.3893</td>
#       <td id="T_83cb9_row1_col5" class="data row1 col5" >0.1598</td>
#     </tr>
#     <tr>
#       <th id="T_83cb9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_83cb9_row2_col0" class="data row2 col0" >0.9033</td>
#       <td id="T_83cb9_row2_col1" class="data row2 col1" >0.9267</td>
#       <td id="T_83cb9_row2_col2" class="data row2 col2" >0.9627</td>
#       <td id="T_83cb9_row2_col3" class="data row2 col3" >-0.1950</td>
#       <td id="T_83cb9_row2_col4" class="data row2 col4" >0.4822</td>
#       <td id="T_83cb9_row2_col5" class="data row2 col5" >0.4824</td>
#     </tr>
#     <tr>
#       <th id="T_83cb9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_
td>
#     </tr>
#     <tr>
#       <th id="T_83cb9_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_83cb9_row10_col0" class="data row10 col0" >0.8433</td>
#       <td id="T_83cb9_row10_col1" class="data row10 col1" >0.8627</td>
#       <td id="T_83cb9_row10_col2" class="data row10 col2" >0.9209</td>
#       <td id="T_83cb9_row10_col3" class="data row10 col3" >-0.2784</td>
#       <td id="T_83cb9_row10_col4" class="data row10 col4" >0.5220</td>
#       <td id="T_83cb9_row10_col5" class="data row10 col5" >0.4060</td>
#     </tr>
#     <tr>
#       <th id="T_83cb9_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_83cb9_row11_col0" class="data row11 col0" >0.1690</td>
#       <td id="T_83cb9_row11_col1" class="data row11 col1" >0.2035</td>
#       <td id="T_83cb9_row11_col2" class="data row11 col2" >0.1209</td>
#       <td id="T_83cb9_row11_col3" class="data row11 col3" >0.2475</td>
#       <td id="T_83cb9_row11_col4" class="data row11 col4" >0.0704</td>
#       <td id="T_83cb9_row11_col5" class="data row11 col5" >0.1376</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Tunning

# %%
# tuned_lasso = tune_model(lasso)
# tuned_lasso_least_angle = tune_model(lasso_least_angle)
# tuned_dummy = tune_model(dummy)
# tuned_elastic = tune_model(elastic)
# tuned_bayesian = tune_model(bayesian)

# %% [markdown]
# ## Blending

# %%
# tuned = [tuned_lasso,
#          tuned_lasso_least_angle,
#          tuned_dummy,
#          tuned_elastic,
#          tuned_bayesian
#         ]
tuned = [lasso,
         lasso_least_angle,
         dummy,
         elastic,
         bayesian
        ]
blender_model = blend_models(tuned)
# Out:
# <style type="text/css">
# #T_c7338_row10_col0, #T_c7338_row10_col1, #T_c7338_row10_col2, #T_c7338_row10_col3, #T_c7338_row10_col4, #T_c7338_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_c7338">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7338_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_c7338_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c7338_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c7338_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_c7338_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_c7338_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7338_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7338_row0_col0" class="data row0 col0" >0.8695</td>
#       <td id="T_c7338_row0_col1" class="data row0 col1" >0.8675</td>
#       <td id="T_c7338_row0_col2" class="data row0 col2" >0.9314</td>
#       <td id="T_c7338_row0_col3" class="data row0 col3" >-0.0121</td>
#       <td id="T_c7338_row0_col4" class="data row0 col4" >0.5129</td>
#       <td id="T_c7338_row0_col5" class="data row0 col5" >0.4466</td>
#     </tr>
#     <tr>
#       <th id="T_c7338_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c7338_row1_col0" class="data row1 col0" >0.4569</td>
#       <td id="T_c7338_row1_col1" class="data row1 col1" >0.4135</td>
#       <td id="T_c7338_row1_col2" class="data row1 col2" >0.6430</td>
#       <td id="T_c7338_row1_col3" class="data row1 col3" >-0.0130</td>
#       <td id="T_c7338_row1_col4" class="data row1 col4" >0.3902</td>
#       <td id="T_c7338_row1_col5" class="data row1 col5" >0.1600</td>
#     </tr>
#     <tr>
#       <th id="T_c7338_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c7338_row2_col0" class="data row2 col0" >0.9064</td>
#       <td id="T_c7338_row2_col1" class="data row2 col1" >0.9347</td>
#       <td id="T_c7338_row2_col2" class="data row2 col2" >0.9668</td>
#       <td id="T_c7338_row2_col3" class="data row2 col3" >-0.2053</td>
#       <td id="T_c7338_row2_col4" class="data row2 col4" >0.4873</td>
#       <td id="T_c7338_row2_col5" class="data row2 col5" >0.4725</td>
#     </tr>
#     <tr>
#       <th id="T_c7338_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c
level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_c7338_row11_col0" class="data row11 col0" >0.1694</td>
#       <td id="T_c7338_row11_col1" class="data row11 col1" >0.1917</td>
#       <td id="T_c7338_row11_col2" class="data row11 col2" >0.1150</td>
#       <td id="T_c7338_row11_col3" class="data row11 col3" >0.2047</td>
#       <td id="T_c7338_row11_col4" class="data row11 col4" >0.0621</td>
#       <td id="T_c7338_row11_col5" class="data row11 col5" >0.1456</td>
#     </tr>
#   </tbody>
# </table>

# %%
"""
finalize_model(): 최종 모델로 설정 후 마지막 학습 진행
predict_model(): 예측 결과를 'Label' 변수에 저장
"""
final_model = finalize_model(blender_model)
prediction = predict_model(final_model, data = test_set)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7e6d7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e6d7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7e6d7_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7e6d7_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_7e6d7_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_7e6d7_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_7e6d7_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_7e6d7_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e6d7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e6d7_row0_col0" class="data row0 col0" >Voting Regressor</td>
#       <td id="T_7e6d7_row0_col1" class="data row0 col1" >0.7875</td>
#       <td id="T_7e6d7_row0_col2" class="data row0 col2" >0.7472</td>
#       <td id="T_7e6d7_row0_col3" class="data row0 col3" >0.8644</td>
#       <td id="T_7e6d7_row0_col4" class="data row0 col4" >0.0584</td>
#       <td id="T_7e6d7_row0_col5" class="data row0 col5" >0.4933</td>
#       <td id="T_7e6d7_row0_col6" class="data row0 col6" >0.3788</td>
#     </tr>
#   </tbody>
# </table>

# %%
prediction
# Out:
#      차선_수  등산객_이용빈도  생태통로_효율성      폭(m)     연장(m)  높이(m)  개방도  경사도  주변 로드킬 빈도  \
# 61    0.0       1.0         1  0.049547 -0.019034    3.1  0.9    5        0.0
# 45    0.0       1.0         1  2.385014 -2.193474    5.0  2.5    6        0.0
# 39    0.0       1.0         2  0.049547 -0.019034    3.1  0.9    6        0.0
# 63    1.0       2.0         2  0.049547 -0.019034    3.1  0.9    5        0.0
# 111   0.0       0.0         2  0.049547 -0.019034    3.1  0.9    4        0.0
# 96    0.0       0.0         2  0.049547 -0.019034    3.1  0.9    4        0.0
# 52    1.0       0.0         0  0.049547 -0.019034    3.1  0.9    5        0.0
# 104   0.0       2.5         0  0.049547 -0.019034    3.1  0.9    1        0.0
# 82    1.0       0.0         0  0.049547 -0.019034    3.1  0.9    3        0.0
# 38    1.0       1.0         0  0.049547 -0.019034    3.1  0.9    3        0.0
# 2     0.0       1.0         0  0.049547 -0.019034    3.1  0.9    4        0.0
# 68    0.0       1.0         2  0.049547 -0.019034    3.1  0.9    2        0.0
# 101   1.0       2.0         0  0.049547 -0.019034    3.1  0.9    5        0.0
# 95    0.0       1.0         0  0.049547 -0.019034    3.1  0.9    3        0.0
# 37    1.0       0.0         1 -2.423301  5.658671    2.5  0.1    6        0.0
# 1     0.0       0.0         1  0.049547 -0.019034    3.1  0.9    2        0.0
# 81    1.0       0.0         2  0.049547 -0.019034    3.1  0.9    3        0.0
# 55    0.0       0.0         2  0.049547 -0.019034    3.1  0.9    3        0.0
# 10    1.0       1.0         0  0.049547 -0.019034    3.1  0.9    2        0.0
# 43    0.0       0.0         2  0.049547 -0.019034    3.1  0.9    3        0.0
# 1     -0.769591 -0.871340         2   -0.998741       11  0.895876
# 81     1.253920 -0.481140         2   -0.299524       11  0.978694
# 55    -0.769591 -0.604491         5   -0.744769        6  0.986083
# 10    -0.769591 -0.269487         5   -0.655801       15  0.891959
# 43    -0.769591 -0.702683         1    0.547665       11  0.891605
# 80     1.415801 -0.104081         2   -0.580916       10  0.993794
# 48    -0.769591 -1.079221         1   -1.028502       15  0.837038
# 47    -0.769591 -1.079221         1   -1.166054       15  0.851339
# 92     1.051569  0.325998         5   -0.587143       10  0.893543
# 26    -0.769591  1.033831         1   -0.705449       13  0.853065
#
# [25 rows x 24 columns]

# %%
test_set
# Out:
#      차선_수  등산객_이용빈도  생태통로_효율성      폭(m)     연장(m)  높이(m)  개방도  경사도  주변 로드킬 빈도  \
# 61    0.0       1.0         1  0.049547 -0.019034    3.1  0.9    5        0.0
# 45    0.0       1.0         1  2.385014 -2.193474    5.0  2.5    6        0.0
# 39    0.0       1.0         2  0.049547 -0.019034    3.1  0.9    6        0.0
# 63    1.0       2.0         2  0.049547 -0.019034    3.1  0.9    5        0.0
# 111   0.0       0.0         2  0.049547 -0.019034    3.1  0.9    4        0.0
# 96    0.0       0.0         2  0.049547 -0.019034    3.1  0.9    4        0.0
# 52    1.0       0.0         0  0.049547 -0.019034    3.1  0.9    5        0.0
# 104   0.0       2.5         0  0.049547 -0.019034    3.1  0.9    1        0.0
# 82    1.0       0.0         0  0.049547 -0.019034    3.1  0.9    3        0.0
# 38    1.0       1.0         0  0.049547 -0.019034    3.1  0.9    3        0.0
# 2     0.0       1.0         0  0.049547 -0.019034    3.1  0.9    4        0.0
# 68    0.0       1.0         2  0.049547 -0.019034    3.1  0.9    2        0.0
# 101   1.0       2.0         0  0.049547 -0.019034    3.1  0.9    5        0.0
# 95    0.0       1.0         0  0.049547 -0.019034    3.1  0.9    3        0.0
# 37    1.0       0.0         1 -2.423301  5.658671    2.5  0.1    6        0.0
# 1     0.0       0.0         1  0.049547 -0.019034    3.1  0.9    2        0.0
# 81    1.0       0.0         2  0.049547 -0.019034    3.1  0.9    3        0.0
# 55    0.0       0.0         2  0.049547 -0.019034    3.1  0.9    3        0.0
# 10    1.0       1.0         0  0.049547 -0.019034    3.1  0.9    2        0.0
# 43    0.0       0.0         2  0.049547 -0.019034    3.1  0.9    3        0.0
# 80    1.0       0.0         2  0.049547 -0.019034    3.1  0.9    5        0.0
# 48    0.0       1.0         0  0.049547 -0.019034    3.1  0.9    4        0.0
# 47    0.0       1.0         0  0.049547 -0.019034    3.1  0.9    6        0.0
# 92    1.0       1.0         0  0.049547 -0.019034    3.1  0.9    5        0.0
# 26    0.0       2.0         1  6.643807 -1.925024    5.3  3.0    6        0.0
#
#      산책로까지의 최단 거리(km)  ...  주변동물 출현빈도  지형기호(2.3km)  하천거리(km)  등산로까지 최단거리(km)  \
# 61          -0.023675  ...  -0.758234            0  0.785413       -0.008601
# 45          -1.672001  ...   0.829827            0  0.218028       -1.195433
# 39           0.289059  ...  -0.758234            0  1.670121       -0.864293
